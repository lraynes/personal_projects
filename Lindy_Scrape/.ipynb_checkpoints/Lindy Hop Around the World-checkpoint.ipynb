# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import plotly
from config import user, apikey
plotly.tools.set_credentials_file(username=user, api_key=apikey)
import plotly.plotly as py
import plotly.figure_factory as ff

# %%
country_codes = pd.read_csv("country_codes.csv", encoding='ISO-8859-1')

# %%
url = "http://dancecal.com/?sMon=1&sYear=2016&num=24&theme=&hidedanceIcon=&list=1&hidetype="
response = requests.get(url)

soup = bs(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <html>
# <head>
# <title>DanceCal.com -  Exchange Calendar -  Workshops Parties Events</title>
# <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/Themes/css/DanceCal.com.css" rel="stylesheet" type="text/css"/>
# <script src="/Themes/js/jquery.js"></script>
# <script src="/Themes/js/DanceCal.com.js"></script>
# <link href="http://DanceCal.com/favicon.gif" rel="SHORTCUT ICON"/>
# </head>
# <body>
# <div class="DCHeader">
# <div class="DCLogoFull">
# <div class="DCLogo">
# <a href="http://DanceCal.com/" name="top">
# <h1>DanceCal.com</h1></a>
# </div>
# <div class="DCTagline">
# <a href="http://DanceCal.com/">
# <h2>Dance Event and Exchange Calendar</h2></a>
# </div>
# <div class="DCSubtagline">
# <h3>Your resource for local and regional dance exchanges, workshops and other events.</h3>
# </div>
# </div>
# <div class="DCMap">
# <center>
# <a href="?map">
# <img align="right" alt="" border="0" height="98" src="/Map.gif" width="220"/>
# <br/>
# <i><b>Event Map</b></i></a>
# </center>
# </div>
# </div>
# <div class="DCMenu">
# <div class="DCMainMenubar">
# <div class="DCMainMenuItem"><a href="http://m.DanceCal.com/" rel="nofollow"><img alt="" border="0" height="19" src="/Pics/Phone.gif" width="12"/> Mobile</a></div>
# <div class="DCMainMenuItem"><a href="/?weekStart=1&amp;num=24&amp;sYear=2016&amp;sMon=1">Calendar</a></div>
# <div class="DCMainMenuItem"><a href="http://DanceCal.com/FAQ/">FAQ</a></div>
# <div class="DCMainMenuItem"><a href="http://DanceCal.com/FAQ/#Why_does_this_calendar_exist">Why</a> DanceCal.com?</div>
# <div class="DCMainMenuItem"><a href="http://Contact.GetDave.com/">Contact Us</a></div>
# <div class="DCMainMenuItem"><a href="/Submit/"><i><b>Add Event</b></i></a></div>
# <div class="DCMainMenuItem">
# <span class="DCMainMenuItemGoogleCal">
# 				Google Cal: click on
# 				<img alt="" border="0" height="13" src="/Pics/gcal.png" width="15"/>
# </span>
# </div>
# </div>
# <div class="DCThemeMenu">
# <form action="/" method="POST" name="themeForm">
# 				Theme:
# 				<select name="theme" onchange="themeForm.submit(); return false;">
# <option value="DanceCal.com">DanceCal.com</option>
# <option value="Empty">Empty</option>
# <option value="Planet">Planet (demo)</option>
# <option value="dcLight">dcLight</option>
# <option value="tmp">tmp</option>
# </select>
# </form>
# </div>
# <div class="DCConfigMenu">
# <div class="DCMenuSet">
# <div class="DCDateMenu">
# <form action="/" class="DCDateMenu" method="GET" name="rangeForm">
# From
# 	<select name="sMon" onchange="this.form.submit();">
# <option selected="" value="1">Jan</option>
# <option value="2">Feb</option>
# <option value="3">Mar</option>
# <option value="4">Apr</option>
# <option value="5">May</option>
# <option value="6">Jun</option>
# <option value="7">Jul</option>
# <option value="8">Aug</option>
# <option value="9">Sep</option>
# <option value="10">Oct</option>
# <option value="11">Nov</option>
# <option value="12">Dec</option>
# </select>
# <select name="sYear" onchange="this.form.submit();">
# <option value="1998">1998</option>
# <option value="1999">1999</option>
# <option value="2000">2000</option>
# <option value="2001">2001</option>
# <option value="2002">2002</option>
# <option value="2003">2003</option>
# <option value="2004">2004</option>
# <option value="2005">2005</option>
# <option value="2006">2006</option>
# <option value="2007">2007</option>
# <option value="2008">2008</option>
# <option value="2009">2009</option>
# <option value="2010">2010</option>
# <option value="2011">2011</option>
# <option value="2012">2012</option>
# <option value="2013">2013</option>
# <option value="2014">2014</option>
# <option value="2015">2015</option>
# <option selected="" value="2016">2016</option>
# <option value="2017">2017</option>
# <option value="2018">2018</option>
# <option value="2019">2019</option>
# <option value="2020">2020</option>
# </select>
# 	showing
# 	<select name="num" onchange="this.form.submit();">
# <option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="11">11</option>
# <option value="12">12</option>
# <option value="13">13</option>
# <option value="14">14</option>
# <option value="15">15</option>
# <option value="16">16</option>
# <option value="17">17</option>
# <option value="18">18</option>
# <option value="19">19</option>
# <option value="20">20</option>
# <option value="21">21</option>
# <option value="22">22</option>
# <option value="23">23</option>
# <option selected="" value="24">24</option>
# <option value="25">25</option>
# <option value="26">26</option>
# <option value="27">27</option>
# <option value="28">28</option>
# <option value="29">29</option>
# <option value="30">30</option>
# </select>
# 	months
# 		<input name="theme" type="hidden" value=""/>
# <input name="list" type="hidden" value="1"/>
# <input name="hidedanceIcon" type="hidden" value=""/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidetype" type="hidden" value=""/>
# <span class="DCMenuGo"><a href="#" onclick="rangeForm.submit(); return false;" rel="nofollow">Go</a></span>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="DCList">
# <div class="DCListMonth">
# <div class="DCListMonthName">January, 2016</div>
# <div class="DCListEvents">
# <div class="DCListEvent">
# <span class="DCListDay">3<span class="DCListDayOrdinal">rd</span></span><span class="DCListName"><a href="http://mxdc.ru/en/" rel="nofollow" target="_blank">Moscow Christmas Swing Dance Camp</a></span>
# <span class="DCListCity">Moscow</span><span class="DCListDance">Lindy, Balboa</span>
# <span class="DCListType">Workshop</span>
# <div class="DCEventInfo DCListEventInfo">
# <span class="DCEventInfoName"><a href="http://mxdc.ru/en/" rel="nofollow" target="_blank">Moscow Christmas Swing Dance Camp</a></span>
# <span class="DCEventInfoFacebook"></span>
# <span class="DCEventInfoGCal"><a href="http://www.google.com/calendar/event?action=TEMPLATE&amp;trp=false&amp;sprop=name:&amp;text=Moscow+Christmas+Swing+Dance+Camp&amp;dates=20160103/20160109&amp;location=Moscow%2c+Russia&amp;details=http%3a%2f%2fmxdc.ru%2fen%2f%0a%0aMoscow+Christmas+Swing+Dance+Camp+takes+place+every+year+January+3rd%2d8th+in+the+comfortable+hotel+in+the+nearest+suburbs+of+Moscow%21+You+are+invited+to+spend+unforgettable+vacations+in+a+best+company+you+can+imagine%2d+top%2dlevel+teachers%2c+enthusiastic+dancers+and+splendid+swing+music%21+Please%2c+feel+free+to+enjoy%3a+%c2%b7+Workshops%3a+Lindy+hop%2c+Boogie+Woogie%2c+West+Coast+Swing%2c+Balboa+and+Solo+jazz.+%c2%b7+Parties%3a+3+dance+floors+every+night+%c2%b7+Jack%2dn%2dJill+and+Knock%2dout+contests+%c2%b7+Amazing+Cabaret+and+shows+%c2%b7+Live+music+%c2%b7+Gifts+and+surprises%0a%0a++%2d+Entry+brought+to+you+by+http%3a%2f%2fDanceCal.com" target="_blank"><img alt="" border="0" height="13" src="Pics/gcal.png" width="15"/></a></span>
# <span class="DCEventInfoDate">1
0a%0a++%2d+Entry+brought+to+you+by+http%3a%2f%2fDanceCal.com" target="_blank"><img alt="" border="0" height="13" src="Pics/gcal.png" width="15"/></a></span>
# <span class="DCEventInfoDate">12/29/2017</span>
# <span class="DCEventInfoWhere">City: Paris, France</span>
# <span class="DCEventInfoDances">Dances: Fusion</span>
# <span class="DCEventInfoDesc">Paris Blues and Fusion New Year Exchange</span>
# </div>
# </div>
# <div class="DCListEvent">
# <span class="DCListDay">29<span class="DCListDayOrdinal">th</span></span><span class="DCListName"><a href="http://tropicthunderkl.com/" rel="nofollow" target="_blank">Tropic Thunder Swing Fest 2017</a></span>
# <span class="DCListCity">Kuala Lumpur</span><span class="DCListDance">Lindy</span>
# <span class="DCListType">Workshop</span>
# <div class="DCEventInfo DCListEventInfo">
# <span class="DCEventInfoName"><a href="http://tropicthunderkl.com/" rel="nofollow" target="_blank">Tropic Thunder Swing Fest 2017</a></span>
# <span class="DCEventInfoFacebook"><a href="https://www.facebook.com/events/130888970885921/?acontext=%7B%22source%22%3A5%2C%22page_id_source%22%3A124264314900051%2C%22action_history%22%3A[%7B%22surface%22%3A%22page%22%2C%22mechanism%22%3A%22main_list%22%2C%22extra_data%22%3A%22%7B%5C%22page_id%5C%22%3A124264314900051%2C%5C%22tour_id%5C%22%3Anull%7D%22%7D]%2C%22has_source%22%3Atrue%7D" rel="nofollow" target="_blank"><img alt="" border="0" height="16" src="Pics/facebook.gif" width="16"/></a></span>
# <span class="DCEventInfoGCal"><a href="http://www.google.com/calendar/event?action=TEMPLATE&amp;trp=false&amp;sprop=name:&amp;text=Tropic+Thunder+Swing+Fest+2017&amp;dates=20171229/20180101&amp;location=Kuala+Lumpur%2c+Malaysia&amp;details=http%3a%2f%2ftropicthunderkl.com%2f%0a%0ahttps%3a%2f%2fwww.facebook.com%2fevents%2f130888970885921%2f%3facontext%3d%257B%2522source%2522%253A5%252C%2522page%5fid%5fsource%2522%253A124264314900051%252C%2522action%5fhistory%2522%253A%5b%257B%2522surface%2522%253A%2522page%2522%252C%2522mechanism%2522%253A%2522main%5flist%2522%252C%2522extra%5fdata%2522%253A%2522%257B%255C%2522page%5fid%255C%2522%253A124264314900051%252C%255C%2522tour%5fid%255C%2522%253Anull%257D%2522%257D%5d%252C%2522has%5fsource%2522%253Atrue%257D%0a%0aThe+inaugural+Tropic+Thunder+is+an+NYE+party+with+3+nights+of+dancing+and+2+days+of+workshops+with+teachers+from+Asia+and+Europe.%0a%0a++%2d+Entry+brought+to+you+by+http%3a%2f%2fDanceCal.com" target="_blank"><img alt="" border="0" height="13" src="Pics/gcal.png" width="15"/></a></span>
# <span class="DCEventInfoDate">12/29/2017</span>
# <span class="DCEventInfoWhere">City: Kuala Lumpur, Malaysia</span>
# <span class="DCEventInfoDances">Dances: Lindy</span>
# <span class="DCEventInfoDesc">The inaugural Tropic Thunder is an NYE party with 3 nights of dancing and 2 days of workshops with teachers from Asia and Europe.</span>
# <span class="DCEventInfoTeachers"><i>Teachers: Sandra Klack, Patrik Pettersson, Sing Lim, Adamas Kim</i></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <br/>
# <div class="DCMenuKey">
# <div class="DCMenuSet">
# <div class="DCDanceMenu">
# <div class="DCDanceChoice">
# <span class="DCCheckbox DCShowDancesChoice"> <form action="/" method="GET" name="formdanceIcon" style="display:inline">
# <input checked="" name="_q" onclick="formdanceIcon.submit(); return false" type="checkbox"/> (show dances)
# 			<input name="num" type="hidden" value="24"/>
# <input name="sYear" type="hidden" value="2016"/>
# <input name="sMon" type="hidden" value="1"/>
# <input name="list" type="hidden" value="1"/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidedanceIcon" type="hidden" value="1"/>
# </form>
# </span></div><div class="DCDanceChoice DCBlues">Blues
# <span class="DCCheckbox"> <form action="/" method="GET" name="formdanceBlues" style="display:inline">
# <input checked="" name="_q" onclick="formdanceBlues.submit(); return false" type="checkbox"/>
# <input name="num" type="hidden" value="24"/>
# <input name="sYear" type="hidden" value="2016"/>
# <input name="sMon" type="hidden" value="1"/>
# <input name="list" type="hidden" value="1"/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidedanceBlues" type="hidden" value="1"/>
# </form>
# </span>
# </div>
# <div class="DCDanceChoice DCLindy">Lindy
# <span class="DCCheckbox"> <form action="/" method="GET" name="formdanceLindy" style="display:inline">
# <input checked="" name="_q" onclick="formdanceLindy.submit(); return false" type="checkbox"/>
# <input name="num" type="hidden" value="24"/>
# <input name="sYear" type="hidden" value="2016"/>
# <input name="sMon" type="hidden" value="1"/>
# <input name="list" type="hidden" value="1"/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidedanceLindy" type="hidden" value="1"/>
# </form>
# </span>
# </div>
# <div class="DCDanceChoice DCBlues DCLindy">(Blues&amp;Lindy;)
# <span class="DCCheckbox"> <form action="/" method="GET" name="formMultdanceBluesLindy" style="display:inline">
# <input name="_q" onclick="formMultdanceBluesLindy.submit(); return false" type="checkbox"/>
# <input name="showDances" type="hidden" value="Blues+Lindy"/>
# </form>
# </span>
# </div>
# <div class="DCDanceChoice DCBalboa">Balboa
# <span class="DCCheckbox"> <form action="/" method="GET" name="formdanceBalboa" style="display:inline">
# <input checked="" name="_q" onclick="formdanceBalboa.submit(); return false" type="checkbox"/>
# <input name="num" type="hidden" value="24"/>
# <input name="sYear" type="hidden" value="2016"/>
# <input name="sMon" type="hidden" value="1"/>
# <input name="list" type="hidden" value="1"/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidedanceBalboa" type="hidden" value="1"/>
# </form>
# </span>
# </div>
# <div class="DCDanceChoice DCSolo_Jazz">Solo Jazz
# <span class="DCCheckbox"> <form action="/" method="GET" name="formdanceSolo_Jazz" style="display:inline">
# <input checked="" name="_q" onclick="formdanceSolo_Jazz.submit(); return false" type="checkbox"/>
# <input name="num" type="hidden" value="24"/>
# <input name="sYear" type="hidden" value="2016"/>
# <input name="sMon" type="hidden" value="1"/>
# <input name="list" type="hidden" value="1"/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidedanceSolo_Jazz" type="hidden" value="1"/>
# </form>
# </span>
# </div>
# <div class="DCDanceChoice DCFusion">Fusion
# <span class="DCCheckbox"> <form action="/" method="GET" name="formdanceFusion" style="display:inline">
# <input checked="" name="_q" onclick="formdanceFusion.submit(); return false" type="checkbox"/>
# <input name="num" type="hidden" value="24"/>
# <input name="sYear" type="hidden" value="2016"/>
# <input name="sMon" type="hidden" value="1"/>
# <input name="list" type="hidden" value="1"/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidedanceFusion" type="hidden" value="1"/>
# </form>
# </span>
# </div>
# </div>
# </div>
# <div class="DCMenuSet">
# <div class="DCTypeMenu">
# <div class="DCTypeChoice DCShowTypesChoice">
# Type:
# <span class="DCCheckbox"> <form action="/" method="GET" name="formtype" style="display:inline">
# <input checked="" name="_q" onclick="formtype.submit(); return false" type="checkbox"/> (show types)
# 			<input name="num" type="hidden" value="24"/>
# <input name="sYear" type="hidden" value="2016"/>
# <input name="sMon" type="hidden" value="1"/>
# <input name="list" type="hidden" value="1"/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidetype" type="hidden" value="1"/>
# </form>
# </span></div><div class="DCTypeChoice"><img alt="W" border="0" class="DCEventType DCWorkshop" height="13" src="/Pics/Types//Workshop.png" valign="bottom" width="13"/> Workshop <span class="DCCheckbox"> <form action="/" method="GET" name="formtypeWorkshop" style="display:inline">
# <input checked="" name="_q" onclick="formtypeWorkshop.submit(); return false" type="checkbox"/>
# <input name="num" type="hidden" value="24"/>
# <input name="sYear" type="hidden" value="2016"/>
# <input name="sMon" type="hidden" value="1"/>
# <input name="list" type="hidden" value="1"/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidetypeWorkshop" type="hidden" value="1"/>
# </form>
# </span>
# </div>
# <div class="DCTypeChoice"><img alt="E" border="0" class="DCEventType DCExchange" height="13" src="/Pics/Types//Exchange.png" valign="bottom" width="13"/> Exchange <span class="DCCheckbox"> <form action="/" method="GET" name="formtypeExchange" style="display:inline">
# <input checked="" name="_q" onclick="formtypeExchange.submit(); return false" type="checkbox"/>
# <input name="num" type="hidden" value="24"/>
# <input name="sYear" type="hidden" value="2016"/>
# <input name="sMon" type="hidden" value="1"/>
# <input name="list" type="hidden" value="1"/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidetypeExchange" type="hidden" value="1"/>
# </form>
# </span>
# </div>
# <div class="DCTypeChoice"><img alt="H" border="0" class="DCEventType DCHouse_Party" height="13" src="/Pics/Types//House_Party.png" valign="bottom" width="13"/> House Party <span class="DCCheckbox"> <form action="/" method="GET" name="formtypeHouse_Party" style="display:inline">
# <input checked="" name="_q" onclick="formtypeHouse_Party.submit(); return false" type="checkbox"/>
# <input name="num" type="hidden" value="24"/>
# <input name="sYear" type="hidden" value="2016"/>
# <input name="sMon" type="hidden" value="1"/>
# <input name="list" type="hidden" value="1"/>
# <input name="weekStart" type="hidden" value="1"/>
# <input name="hidetypeHouse_Party" type="hidden" value="1"/>
# </form>
# </span>
# </div>
# </div>
# </div>
# <div class="DCMenuSet">
# <div class="DCSearch">
# <form action="/" method="GET">
# 				Search:
# 				<input class="boxed" name="q" onfocus="this.value=''" size="12" type="text" value="&lt;search&gt;"> <a href="/?num=24&amp;sYear=2016&amp;sMon=1&amp;list=1&amp;weekStart=1">☒</a>
# </input></form>
# </div>
# </div>
# </div>
# <div class="DCFooter">
# <p>
# <center>
# Software/hosting by <a href="http://GetDave.com/">Dave's</a>
# <a href="http://MarginalHacks.com/">Marginal Hacks</a>
# </center>
# </p></div>
# </body>
# </html>

# %%
lindy_list = []
for x in soup.find_all('div', class_="DCListEvent"):
    try:
        name = x.find('span', class_="DCEventInfoName").text
        genre = x.find('span', class_="DCEventInfoDances").text[8:].split(", ")
        date = x.find('span', class_="DCEventInfoDate").text
        
        if len(x.find('span', class_="DCEventInfoWhere").text[6:].split(", ")) == 1:
            location = x.find('span', class_="DCEventInfoWhere").text[6:].split(", ")[0]
        elif len(x.find('span', class_="DCEventInfoWhere").text[6:].split(", ")) == 2:
            location = x.find('span', class_="DCEventInfoWhere").text[6:].split(", ")[1]
        elif len(x.find('span', class_="DCEventInfoWhere").text[6:].split(", ")) == 3:
            location = x.find('span', class_="DCEventInfoWhere").text[6:].split(", ")[2]
        elif len(x.find('span', class_="DCEventInfoWhere").text[6:].split(", ")) == 4:
            location = x.find('span', class_="DCEventInfoWhere").text[6:].split(", ")[3]
        else:
            location = "error"


        lindy_list.append({
            "Name": name,
            "Genre": genre,
            "Date": date,
            "Location": location
        })
    except AttributeError as e:
        print(e)
lindy_list
# Out:
# 'NoneType' object has no attribute 'text'
# [{'Name': 'Moscow Christmas Swing Dance Camp',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '1/3/2016',
#   'Location': 'Russia'},
#  {'Name': 'Krakow Lindy Invasion',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '1/8/2016',
#   'Location': 'Poland'},
#  {'Name': 'California Balboa Classic 2016',
#   'Genre': ['Balboa'],
#   'Date': '1/15/2016',
#   'Location': 'USA'},
#  {'Name': 'City In Motion Dance Weekend',
#   'Genre': ['Fusion'],
#   'Date': '1/15/2016',
#   'Location': 'USA'},
#  {'Name': 'DecoDance at Art Deco Weekend',
#   'Genre': ['Lindy'],
#   'Date': '1/15/2016',
#   'Location': 'USA'},
#  {'Name': 'LiLi Hop',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '1/15/2016',
#   'Location': 'Belgium'},
#  {'Name': 'My Lindy Kraze',
#   'Genre': ['Lindy', 'Shag'],
#   'Date': '1/15/2016',
#   'Location': 'USA'},
#  {'Name': 'Anderson Blues & Lindy Experience',
#   'Genre': ['Blues', 'Lindy', 'Shag'],
#   'Date': '1/22/2016',
#   'Location': 'USA'},
#  {'Name': 'Freedom Swing',
#   'Genre': ['West Coast'],
#   'Date': '1/22/2016',
#   'Location': 'USA'},
#  {'Name': "Jumpin' January",
#   'Genre': ['Lindy', 'Shag'],
#   'Date': '1/22/2016',
#   'Location': 'Switzerland'},
#  {'Name': 'Kind of A Big Deal Weekend',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '1/22/2016',
#   'Location': 'USA'},
#  {'Name': 'Peter & Naomi Workshop Weekend',
#   'Genre': ['Lindy'],
#   'Date': '1/22/2016',
#   'Location': 'USA'},
#  {'Name': 'Swing Camp OZ 2016',
#   'Genre': ['Lindy', 'Balboa', 'Shag'],
#   'Date': '1/22/2016',
#   'Location': 'Australia'},
#  {'Name': 'ESS WCS Camp',
#   'Genre': ['West Coast'],
#   'Date': '1/28/2016',
#   'Location': 'USA'},
#  {'Name': 'Balboa Dayz 2016',
#   'Genre': ['Balboa'],
#   'Date': '1/29/2016',
#   'Location': 'Germany'},
#  {'Name': 'Breizh Blues Invasion',
#   'Genre': ['Blues'],
#   'Date': '1/29/2016',
#   'Location': 'France'},
#  {'Name': 'DJam 2016',
#   'Genre': ['Blues', 'Lindy', 'Balboa'],
#   'Date': '1/29/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'Hot Rhythm Holiday 2016',
#   'Genre': ['Lindy', 'Balboa', 'Shag'],
#   'Date': '1/29/2016',
#   'Location': 'USA'},
#  {'Name': 'Scandinavian Shuffle',
#   'Genre': ['Balboa'],
#   'Date': '1/29/2016',
#   'Location': 'Denmark'},
#  {'Name': 'Spirit Movements',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '1/29/2016',
#   'Location': 'France'},
#  {'Name': 'Winter Blues',
#   'Genre': ['Blues'],
#   'Date': '1/29/2016',
#   'Location': 'USA'},
#  {'Name': 'Super Swing Fest 2016: Lindy Lions Free Weekend Workshop',
#   'Genre': ['Lindy'],
#   'Date': '1/30/2016',
#   'Location': 'USA'},
#  {'Name': 'The First Cozy Catania Hop',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '1/30/2016',
#   'Location': 'Italy'},
#  {'Name': 'Winter Fusion Project 2016',
#   'Genre': ['Fusion'],
#   'Date': '1/30/2016',
#   'Location': 'Canada'},
#  {'Name': '11th Rock That Swing Festival',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'Boogie Woogie', 'Other'],
#   'Date': '2/4/2016',
#   'Location': 'Germany'},
#  {'Name': '26th Workuba International, Havana',
#   'Genre': ['Tango', 'Other'],
#   'Date': '2/4/2016',
#   'Location': 'Cuba'},
#  {'Name': 'Charlotte Westie Fest',
#   'Genre': ['West Coast'],
#   'Date': '2/5/2016',
#   'Location': 'USA'},
#  {'Name': 'Cider House Blues',
#   'Genre': ['Blues'],
#   'Date': '2/5/2016',
#   'Location': 'Australia'},
#  {'Name': 'Jazz with Ramona',
#   'Genre': ['Solo Jazz'],
#   'Date': '2/5/2016',
#   'Location': 'New Zealand'},
#  {'Name': 'SparX',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '2/5/2016',
#   'Location': 'USA'},
#  {'Name': 'Sweet Swingouts',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/5/2016',
#   'Location': 'USA'},
#  {'Name': 'University of Swing',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/5/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'Winter Black Swing Festival',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/5/2016',
#   'Location': 'Spain'},
#  {'Name': '5-6 Jazz with Ramona',
#   'Genre': ['Solo Jazz'],
#   'Date': '2/6/2016',
#   'Location': 'Australia'},
#  {'Name': 'Blues Weekend Rosario 2016',
#   'Genre': ['Blues'],
#   'Date': '2/6/2016',
#   'Location': 'Argentina'},
#  {'Name': 'Fancy Feet with Lauren and Pete',
#   'Genre': ['Lindy', 'Balboa', 'Shag'],
#   'Date': '2/6/2016',
#   'Location': 'Australia'},
#  {'Name': 'Join In Throw Out! With Mel & Jo',
#   'Genre': ['Balboa'],
#   'Date': '2/6/2016',
#   'Location': 'United Kingdom'},
#  {'Name': "Leapin' Lindy",
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/11/2016',
#   'Location': 'Switzerland'},
#  {'Name': 'Crash! Blues Festival Delft',
#   'Genre': ['Blues'],
#   'Date': '2/12/2016',
#   'Location': 'Netherlands'},
#  {'Name': 'Flurry Festival',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Other'],
#   'Date': '2/12/2016',
#   'Location': 'USA'},
#  {'Name': 'Jenny & Dan Workshop Weekend',
#   'Genre': ['Blues'],
#   'Date': '2/12/2016',
#   'Location': 'USA'},
#  {'Name': 'Joe DeMers & Campbell Miller Workshops',
#   'Genre': ['Blues'],
#   'Date': '2/12/2016',
#   'Location': 'USA'},
#  {'Name': 'Mo Better Blues 2016',
#   'Genre': ['Blues'],
#   'Date': '2/12/2016',
#   'Location': 'USA'},
#  {'Name': 'Rock Chalk Swing 2016',
#   'Genre': ['Lindy'],
#   'Date': '2/12/2016',
#   'Location': 'USA'},
#  {'Name': "Valentine's Blues Fever",
#   'Genre': ['Blues'],
#   'Date': '2/12/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'Peter Flahiff & Lauren Stanley Workshop',
#   'Genre': ['Lindy', 'Balboa', 'Shag'],
#   'Date': '2/13/2016',
#   'Location': 'Australia'},
#  {'Name': 'Art Deco',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '2/18/2016',
#   'Location': 'New Zealand'},
#  {'Name': 'Edinburgh Balboa Weekend 2016',
#   'Genre': ['Balboa'],
#   'Date': '2/19/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'Lindy Diversion',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz'],
#   'Date': '2/19/2016',
#   'Location': 'USA'},
#  {'Name': 'Lindylicious',
#   'Genre': ['Lindy'],
#   'Date': '2/19/2016',
#   'Location': 'France'},
#  {'Name': 'Peter Flahiff workshops - Auckland',
#   'Genre': ['Lindy', 'Balboa', 'Shag'],
#   'Date': '2/19/2016',
#   'Location': 'New Zealand'},
#  {'Name': 'Rain City Blues 2016',
#   'Genre': ['Blues'],
#   'Date': '2/19/2016',
#   'Location': 'USA'},
#  {'Name': 'Swing Into Spring 2016',
#   'Genre': ['Lindy'],
#   'Date': '2/19/2016',
#   'Location': 'USA'},
#  {'Name': 'Australasian WCS & Zouk Championships',
#   'Genre': ['West Coast', 'Other'],
#   'Date': '2/25/2016',
#   'Location': 'Australia'},
#  {'Name': " Swingin' Genova Weekend",
#   'Genre': ['Lindy'],
#   'Date': '2/26/2016',
#   'Location': 'Italy'},
#  {'Name': 'Big Bang Swing',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/26/2016',
#   'Location': 'Thailand'},
#  {'Name': 'Dayton Swing Smackdown',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/26/2016',
#   'Location': 'USA'},
#  {'Name': 'Hawkeye Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '2/26/2016',
#   'Location': 'USA'},
#  {'Name': 'Just Swing It',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '2/26/2016',
#   'Location': 'Italy'},
#  {'Name': 'Oxford Swing Festival',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz'],
#   'Date': '2/26/2016',
#   'Location': 'United Kingdom'},
#  {'Name': "Swingin' At The Savoy 2016 with NORMA MILLER, CHAZZ YOUNG, CHESTER WHITMORE, and more!",
#   'Genre': ['Lindy'],
#   'Date': '2/26/2016',
#   'Location': 'USA'},
#  {'Name': 'For Dancers Only 2016',
#   'Genre': ['Lindy', 'Balboa', 'Shag'],
#   'Date': '2/27/2016',
#   'Location': 'Australia'},
#  {'Name': 'LaBLove 2016',
#   'Genre': ['Blues', 'Lindy', 'Balboa'],
#   'Date': '2/27/2016',
#   'Location': 'USA'},
#  {'Name': ' Berlin Balboa Weekend',
#   'Genre': ['Balboa'],
#   'Date': '3/3/2016',
#   'Location': 'Germany'},
#  {'Name': 'MADjam',
#   'Genre': ['West Coast'],
#   'Date': '3/3/2016',
#   'Location': 'USA'},
#  {'Name': 'Move Your Bottom',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '3/3/2016',
#   'Location': 'Spain'},
#  {'Name': 'Brown Ale Blues 2016',
#   'Genre': ['Fusion'],
#   'Date': '3/4/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'Keep This Date Saved! Peter Flahiff And Lauren Stanley Workshops',
#   'Genre': ['Balboa', 'Shag'],
#   'Date': '3/4/2016',
#   'Location': 'Australia'},
#  {'Name': 'Mini Swede Swing Weekend',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '3/4/2016',
#   'Location': 'Belgium'},
#  {'Name': 'Orlando Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '3/4/2016',
#   'Location': 'USA'},
#  {'Name': 'Steel City Blues Festival',
#   'Genre': ['Blues'],
#   'Date': '3/4/2016',
#   'Location': 'USA'},
#  {'Name': 'Randy & Kara Balboa Workshops',
#   'Genre': ['Balboa'],
#   'Date': '3/5/2016',
#   'Location': 'USA'},
#  {'Name': 'Chicago Classic',
#   'Genre': ['West Coast'],
#   'Date': '3/10/2016',
#   'Location': 'USA'},
#  {'Name': 'Ljubljana Sweetswing Festival',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '3/10/2016',
#   'Location': 'Slovenia'},
#  {'Name': 'Mission Fusion Extravaganza',
#   'Genre': ['Fusion'],
#   'Date': '3/10/2016',
#   'Location': 'USA'},
#  {'Name': 'Cocoa Blues Exchange',
#   'Genre': ['Fusion'],
#   'Date': '3/11/2016',
#   'Location': 'Spain'},
#  {'Name': 'Perth Lindy Jam 2016',
#   'Genre': ['Lindy'],
#   'Date': '3/11/2016',
#   'Location': 'Australia'},
#  {'Name': 'Pirate Swing',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz'],
#   'Date': '3/11/2016',
#   'Location': 'USA'},
#  {'Name': 'The Blues Garden',
#   'Genre': ['Blues'],
#   'Date': '3/11/2016',
#   'Location': 'Sweden'},
#  {'Name': 'The Music City Exchange',
#   'Genre': ['Lindy'],
#   'Date': '3/11/2016',
#   'Location': 'USA'},
#  {'Name': 'Australian Lindy Hop Championships',
#   'Genre': ['Lindy'],
#   'Date': '3/12/2016',
#   'Location': 'Australia'},
#  {'Name': 'Boston Tea Party',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'West Coast'],
#   'Date': '3/17/2016',
#   'Location': 'USA'},
#  {'Name': "Cruisin' for a Bluesin' 16",
#   'Genre': ['Blues'],
#   'Date': '3/17/2016',
#   'Location': 'USA'},
#  {'Name': 'Backwater Blues 2016',
#   'Genre': ['Blues'],
#   'Date': '3/18/2016',
#   'Location': 'USA'},
#  {'Name': 'Fair City Blues 2015',
#   'Genre': ['Blues'],
#   'Date': '3/18/2016',
#   'Location': 'Ireland'},
#  {'Name': 'Marckolswing! Swing dance workshop',
#   'Genre': ['Lindy'],
#   'Date': '3/18/2016',
#   'Location': 'France'},
#  {'Name': 'Minsk Lindy Exchange',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '3/18/2016',
#   'Location': 'Belarus'},
#  {'Name': 'Toronto Toss Out',
#   'Genre': ['Balboa'],
#   'Date': '3/18/2016',
#   'Location': 'Canada'},
#  {'Name': 'Vienna Balboa & Laminu Experience 2016',
#   'Genre': ['Balboa', 'Other'],
#   'Date': '3/18/2016',
#   'Location': 'Austria'},
#  {'Name': 'Mother City Hop',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '3/19/2016',
#   'Location': 'South Africa'},
#  {'Name': 'Barswingona',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '3/21/2016',
#   'Location': 'Spain'},
#  {'Name': 'Easter Swing',
#   'Genre': ['West Coast'],
#   'Date': '3/24/2016',
#   'Location': 'USA'},
#  {'Name': 'No. 8 Balboa',
#   'Genre': ['Balboa'],
#   'Date': '3/24/2016',
#   'Location': 'New Zealand'},
#  {'Name': 'Stockholm Tap Festival',
#   'Genre': ['Other'],
#   'Date': '3/24/2016',
#   'Location': 'Sweden'},
#  {'Name': 'Bal Bootcamp',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '3/25/2016',
#   'Location': 'USA'},
#  {'Name': 'Burg is the Word',
#   'Genre': ['Lindy'],
#   'Date': '3/25/2016',
#   'Location': 'USA'},
#  {'Name': 'Swing Over Orlando',
#   'Genre': ['West Coast'],
#   'Date': '3/25/2016',
#   'Location': 'USA'},
#  {'Name': 'Emerald Coast Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '3/31/2016',
#   'Location': 'USA'},
#  {'Name': 'Heartland Swing Festival & Collegiate Jitterbug Championships',
#   'Genre': ['Lindy'],
#   'Date': '3/31/2016',
#   'Location': 'USA'},
#  {'Name': 'Lindy Bout',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '3/31/2016',
#   'Location': 'Canada'},
#  {'Name': 'Austin Blues Party 9',
#   'Genre': ['Blues'],
#   'Date': '4/1/2016',
#   'Location': 'USA'},
#  {'Name': 'Beach Bum Blues',
#   'Genre': ['Blues'],
#   'Date': '4/1/2016',
#   'Location': 'USA'},
#  {'Name': 'Blusion',
#   'Genre': ['Fusion'],
#   'Date': '4/1/2016',
#   'Location': 'USA'},
#  {'Name': 'Falcon Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '4/1/2016',
#   'Location': 'USA'},
#  {'Name': "Gentse Hoppers Exchange '16",
#   'Genre': ['Blues', 'Lindy', 'Balboa'],
#   'Date': '4/1/2016',
#   'Location': 'Belgium'},
#  {'Name': 'Miami University Dance Exchange',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '4/1/2016',
#   'Location': 'USA'},
#  {'Name': 'Roaring Twenties Weekend',
#   'Genre': ['Lindy', 'Tango', 'Solo Jazz', 'Shag'],
#   'Date': '4/1/2016',
#   'Location': 'USA'},
#  {'Name': 'Saint Petersburg Balboa Weekend',
#   'Genre': ['Balboa'],
#   'Date': '4/1/2016',
#   'Location': 'Russia'},
#  {'Name': 'SwingOut Tokyo',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '4/1/2016',
#   'Location': 'Japan'},
#  {'Name': 'Hot Night Fusion Exchange',
#   'Genre': ['Fusion'],
#   'Date': '4/5/2016',
#   'Location': 'USA'},
#  {'Name': 'Recess Gender Bender Action Camp',
#   'Genre': ['Fusion'],
#   'Date': '4/6/2016',
#   'Location': 'USA'},
#  {'Name': 'Fleur De Lindy',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '4/7/2016',
#   'Location': 'USA'},
#  {'Name': 'Appalachia Recess',
#   'Genre': ['Fusion'],
#   'Date': '4/8/2016',
#   'Location': 'USA'},
#  {'Name': 'Chorus Girl Camp',
#   'Genre': ['Solo Jazz'],
#   'Date': '4/8/2016',
#   'Location': 'USA'},
#  {'Name': 'InterCollegiate Swing Battle',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz'],
#   'Date': '4/8/2016',
#   'Location': 'USA'},
#  {'Name': 'Jenny & Dan Blues Workshops',
#   'Genre': ['Blues'],
#   'Date': '4/8/2016',
#   'Location': 'USA'},
#  {'Name': 'Lafayette Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '4/8/2016',
#   'Location': 'USA'},
#  {'Name': 'Spring Workshop with Caitlin Wellman in Montreal',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '4/8/2016',
#   'Location': 'Canada'},
#  {'Name': 'Swing Paradise 2016',
#   'Genre': ['Balboa', 'Shag'],
#   'Date': '4/8/2016',
#   'Location': 'Lithuania'},
#  {'Name': 'Mexico Dance Retreat',
#   'Genre': ['Other'],
#   'Date': '4/9/2016',
#   'Location': 'Mexico'},
#  {'Name': 'Sugar Push Swing Dance Retreat',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'Boogie Woogie'],
#   'Date': '4/10/2016',
#   'Location': 'France'},
#  {'Name': 'Lindy on Track',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '4/12/2016',
#   'Location': 'Poland'},
#  {'Name': 'bluesSHOUT! 2016',
#   'Genre': ['Blues'],
#   'Date': '4/14/2016',
#   'Location': 'USA'},
#  {'Name': 'Washington DC Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '4/14/2016',
#   'Location': 'USA'},
#  {'Name': '505 Stomp',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '4/15/2016',
#   'Location': 'USA'},
#  {'Name': 'Down South Camp Meeting',
#   'Genre': ['Lindy', 'Shag'],
#   'Date': '4/15/2016',
#   'Location': 'USA'},
#  {'Name': 'Eesti Spring Swing',
#   'Genre': ['West Coast'],
#   'Date': '4/15/2016',
#   'Location': 'Estonia'},
#  {'Name': 'Jumptown Jam 2016',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '4/15/2016',
#   'Location': 'Australia'},
#  {'Name': 'New Orleans Clandestino Recess',
#   'Genre': ['Fusion'],
#   'Date': '4/15/2016',
#   'Location': 'USA'},
#  {'Name': 'Sunflower Swing',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '4/15/2016',
#   'Location': 'USA'},
#  {'Name': 'WILLOW BLUES _ First Lodz Blues Exchange',
#   'Genre': ['Blues'],
#   'Date': '4/15/2016',
#   'Location': 'Poland'},
#  {'Name': 'Hullabaloo 2016',
#   'Genre': ['Lindy', 'Balboa', 'Shag'],
#   'Date': '4/21/2016',
#   'Location': 'Australia'},
#  {'Name': 'Montreal Bagel n Blues',
#   'Genre': ['Blues'],
#   'Date': '4/21/2016',
#   'Location': 'Canada'},
#  {'Name': 'Portland Underground Exchange',
#   'Genre': ['Fusion'],
#   'Date': '4/22/2016',
#   'Location': 'USA'},
#  {'Name': 'Prague Blues eXchange',
#   'Genre': ['Blues'],
#   'Date': '4/22/2016',
#   'Location': 'Czech Republic'},
#  {'Name': 'Rocky Mountain Girl Jam',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Other'],
#   'Date': '4/22/2016',
#   'Location': 'USA'},
#  {'Name': 'Spring Fling Balboa Weekend',
#   'Genre': ['Balboa'],
#   'Date': '4/22/2016',
#   'Location': 'USA'},
#  {'Name': 'St. Louis Shag Intensive',
#   'Genre': ['Shag'],
#   'Date': '4/22/2016',
#   'Location': 'USA'},
#  {'Name': 'The Lindy Camp',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '4/22/2016',
#   'Location': 'Sweden'},
#  {'Name': 'Dirty Dozen Weekend',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '4/28/2016',
#   'Location': 'USA'},
#  {'Name': 'Cali Creek Mendocino Recess',
#   'Genre': ['Fusion'],
#   'Date': '4/29/2016',
#   'Location': 'USA'},
#  {'Name': "Fallin' In Blues",
#   'Genre': ['Blues'],
#   'Date': '4/29/2016',
#   'Location': 'France'},
#  {'Name': 'London Lindy Exchange',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '4/29/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'San Luis Obispo Lindy Exchange 2016',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '4/29/2016',
#   'Location': 'USA'},
#  {'Name': 'Swinglandia',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '4/29/2016',
#   'Location': 'Ukraine'},
#  {'Name': 'Sydney Blues 2.0',
#   'Genre': ['Blues'],
#   'Date': '4/29/2016',
#   'Location': 'Australia'},
#  {'Name': 'Tallinn Swing Weekend',
#   'Genre': ['Lindy'],
#   'Date': '4/29/2016',
#   'Location': 'Estonia'},
#  {'Name': 'Copenhagen Lindy Exchange',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/4/2016',
#   'Location': 'Denmark'},
#  {'Name': ' Stockholm Blues Fest 2016: The Retreat',
#   'Genre': ['Blues'],
#   'Date': '5/5/2016',
#   'Location': 'Sweden'},
#  {'Name': "Crep' Swing Festival 2016",
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/5/2016',
#   'Location': 'France'},
#  {'Name': 'Midwest Lindy Fest',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/5/2016',
#   'Location': 'USA'},
#  {'Name': 'Desert Stomp',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/6/2016',
#   'Location': 'Israel'},
#  {'Name': 'Portland Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '5/6/2016',
#   'Location': 'USA'},
#  {'Name': 'Southbound Blues Exchange 2016',
#   'Genre': ['Blues'],
#   'Date': '5/6/2016',
#   'Location': 'USA'},
#  {'Name': 'Swing Out Savannah',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/6/2016',
#   'Location': 'USA'},
#  {'Name': 'Swing Out Savannah 5',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz', 'Other'],
#   'Date': '5/6/2016',
#   'Location': 'USA'},
#  {'Name': 'Blossom Blues Camp 2016',
#   'Genre': ['Fusion'],
#   'Date': '5/7/2016',
#   'Location': 'Switzerland'},
#  {'Name': "Got'em Blues Leipzig",
#   'Genre': ['Blues'],
#   'Date': '5/7/2016',
#   'Location': 'Germany'},
#  {'Name': 'Heedman Workshop in Visby, Sweden',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/7/2016',
#   'Location': 'Sweden'},
#  {'Name': 'Aires de Blues',
#   'Genre': ['Blues'],
#   'Date': '5/13/2016',
#   'Location': 'Argentina'},
#  {'Name': 'Big Apple Balboa Blues and Liindy Hop Exchange',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '5/13/2016',
#   'Location': 'USA'},
#  {'Name': 'Blossom Blues 2016',
#   'Genre': ['Fusion'],
#   'Date': '5/13/2016',
#   'Location': 'Switzerland'},
#  {'Name': 'Istanbul Lindy Exchange',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/13/2016',
#   'Location': 'Turkey'},
#  {'Name': 'Little Big Weekend 13-15 May 2016',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/13/2016',
#   'Location': 'Australia'},
#  {'Name': 'Moscow Balboa Weekend',
#   'Genre': ['Balboa'],
#   'Date': '5/13/2016',
#   'Location': 'Russia'},
#  {'Name': 'Northwest Balboa Festival',
#   'Genre': ['Balboa'],
#   'Date': '5/13/2016',
#   'Location': 'USA'},
#  {'Name': 'Plenty Hot 2016',
#   'Genre': ['Lindy'],
#   'Date': '5/13/2016',
#   'Location': 'Germany'},
#  {'Name': 'School of Hard Knox',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '5/13/2016',
#   'Location': 'USA'},
#  {'Name': 'Camp Dixieland',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'Boogie Woogie'],
#   'Date': '5/19/2016',
#   'Location': 'Germany'},
#  {'Name': 'Harlem',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '5/19/2016',
#   'Location': 'Lithuania'},
#  {'Name': 'All The Cats Join In ',
#   'Genre': ['Balboa', 'Shag'],
#   'Date': '5/20/2016',
#   'Location': 'Australia'},
#  {'Name': 'BluesQuake 2016',
#   'Genre': ['Blues'],
#   'Date': '5/20/2016',
#   'Location': 'USA'},
#  {'Name': 'Charleston Lindy Exchange 2016',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '5/20/2016',
#   'Location': 'USA'},
#  {'Name': 'Columbus Lindy & Blues Exchange',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '5/20/2016',
#   'Location': 'USA'},
#  {'Name': 'European Gender Bender',
#   'Genre': ['Fusion'],
#   'Date': '5/20/2016',
#   'Location': 'Spain'},
#  {'Name': 'MooseBlues',
#   'Genre': ['Blues'],
#   'Date': '5/20/2016',
#   'Location': 'Norway'},
#  {'Name': 'Sunshine Swing - Brisbane Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '5/20/2016',
#   'Location': 'Australia'},
#  {'Name': 'Dive into Blues Special',
#   'Genre': ['Blues'],
#   'Date': '5/21/2016',
#   'Location': 'Germany'},
#  {'Name': 'European Blues Experience',
#   'Genre': ['Fusion'],
#   'Date': '5/26/2016',
#   'Location': 'Spain'},
#  {'Name': 'Greenwood Swingout',
#   'Genre': ['Lindy'],
#   'Date': '5/26/2016',
#   'Location': 'USA'},
#  {'Name': 'Mojo Swing Festival',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/26/2016',
#   'Location': 'Spain'},
#  {'Name': 'Red Hot Blues & BBQ',
#   'Genre': ['Blues'],
#   'Date': '5/26/2016',
#   'Location': 'USA'},
#  {'Name': 'Smokey Feet',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/26/2016',
#   'Location': 'Netherlands'},
#  {'Name': 'USA Grand National Dance Championship',
#   'Genre': ['Shag', 'West Coast'],
#   'Date': '5/26/2016',
#   'Location': 'USA'},
#  {'Name': 'Camp Jitterbug',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '5/27/2016',
#   'Location': 'USA'},
#  {'Name': 'Richmond Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '5/27/2016',
#   'Location': 'USA'},
#  {'Name': 'Seaside Stomp',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '5/27/2016',
#   'Location': 'USA'},
#  {'Name': " Swingin' Spring 2016",
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '6/3/2016',
#   'Location': 'Sweden'},
#  {'Name': 'Hot Blues 2016',
#   'Genre': ['Blues'],
#   'Date': '6/3/2016',
#   'Location': 'France'},
#  {'Name': 'Kyle & Sarah in DC',
#   'Genre': ['West Coast'],
#   'Date': '6/3/2016',
#   'Location': 'USA'},
#  {'Name': 'Live Love Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '6/3/2016',
#   'Location': 'USA'},
#  {'Name': 'Mike & Joe Nova Blues Workshop Weekend',
#   'Genre': ['Blues'],
#   'Date': '6/3/2016',
#   'Location': 'Canada'},
#  {'Name': 'MiniGUINEA: West African Dance and Drum Retreat',
#   'Genre': ['Other'],
#   'Date': '6/3/2016',
#   'Location': 'USA'},
#  {'Name': 'Stompology Solo Jazz Weekend',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '6/3/2016',
#   'Location': 'USA'},
#  {'Name': 'Tango Meets the Blues',
#   'Genre': ['Blues', 'Tango'],
#   'Date': '6/3/2016',
#   'Location': 'USA'},
#  {'Name': 'The Glasgow Getdown 2016',
#   'Genre': ['Blues', 'Lindy', 'Balboa'],
#   'Date': '6/3/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'Swing & Swim International Dance Camp',
#   'Genre': ['Lindy', 'Solo Jazz', 'Other'],
#   'Date': '6/6/2016',
#   'Location': 'Greece'},
#  {'Name': ' Warsaw Lindy Hop Exchange',
#   'Genre': ['Lindy'],
#   'Date': '6/9/2016',
#   'Location': 'Poland'},
#  {'Name': 'Old World Alt-Blues Recess',
#   'Genre': ['Fusion'],
#   'Date': '6/9/2016',
#   'Location': 'Italy'},
#  {'Name': 'Rovinj Swing Festival',
#   'Genre': ['Lindy'],
#   'Date': '6/9/2016',
#   'Location': 'Croatia'},
#  {'Name': 'VBLX2016',
#   'Genre': ['Lindy'],
#   'Date': '6/9/2016',
#   'Location': 'USA'},
#  {'Name': 'Chicago Underground Blues Experience',
#   'Genre': ['Blues'],
#   'Date': '6/10/2016',
#   'Location': 'USA'},
#  {'Name': 'Paris Blues Exchange 2016',
#   'Genre': ['Fusion'],
#   'Date': '6/10/2016',
#   'Location': 'France'},
#  {'Name': 'Ruth & Mike - THE RETURN',
#   'Genre': ['Blues'],
#   'Date': '6/10/2016',
#   'Location': 'Netherlands'},
#  {'Name': 'Southern Swing Challenge',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '6/10/2016',
#   'Location': 'USA'},
#  {'Name': 'All Balboa Weekend',
#   'Genre': ['Balboa'],
#   'Date': '6/16/2016',
#   'Location': 'USA'},
#  {'Name': 'Delta Blues Festival',
#   'Genre': ['Blues'],
#   'Date': '6/16/2016',
#   'Location': 'Spain'},
#  {'Name': 'European Blues Invasion',
#   'Genre': ['Fusion'],
#   'Date': '6/16/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'Roma Lindy Exchange',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'Boogie Woogie'],
#   'Date': '6/16/2016',
#   'Location': 'Italy'},
#  {'Name': 'Big Sky Weekend',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '6/17/2016',
#   'Location': 'USA'},
#  {'Name': 'Blues Battle',
#   'Genre': ['Blues'],
#   'Date': '6/17/2016',
#   'Location': 'Canada'},
#  {'Name': 'Stockamöllan Jazz Music & Dance Festival',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '6/17/2016',
#   'Location': 'Sweden'},
#  {'Name': 'Beantown Camp',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '6/23/2016',
#   'Location': 'USA'},
#  {'Name': 'Cozy Catania Hop Summer Edition',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '6/23/2016',
#   'Location': 'Italy'},
#  {'Name': 'Greenville Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '6/24/2016',
#   'Location': 'USA'},
#  {'Name': 'Mile High Blues 2016',
#   'Genre': ['Blues'],
#   'Date': '6/24/2016',
#   'Location': 'USA'},
#  {'Name': 'Sydney International Swing Dance Festival',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '6/24/2016',
#   'Location': 'Australia'},
#  {'Name': 'Tiny Blues Weekend 2016',
#   'Genre': ['Blues'],
#   'Date': '6/24/2016',
#   'Location': 'Germany'},
#  {'Name': 'Winter Swing Festival 2016',
#   'Genre': ['Lindy'],
#   'Date': '6/24/2016',
#   'Location': 'Australia'},
#  {'Name': 'The Spoonful',
#   'Genre': ['Blues'],
#   'Date': '6/30/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'Blue Ridge Bal',
#   'Genre': ['Balboa'],
#   'Date': '7/1/2016',
#   'Location': 'USA'},
#  {'Name': 'SWINGdepenDANCE Workshop Weekend',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '7/1/2016',
#   'Location': 'USA'},
#  {'Name': 'Herräng Dance Camp week 1',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '7/2/2016',
#   'Location': 'Sweden'},
#  {'Name': 'Blues in Pistoia',
#   'Genre': ['Blues'],
#   'Date': '7/8/2016',
#   'Location': 'Italy'},
#  {'Name': 'Dance Out Loud: Closer Encounters',
#   'Genre': ['Fusion'],
#   'Date': '7/8/2016',
#   'Location': 'USA'},
#  {'Name': 'Montreal Swing Riot',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '7/8/2016',
#   'Location': 'Canada'},
#  {'Name': 'Swing in corsica',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '7/8/2016',
#   'Location': 'France'},
#  {'Name': "Swingin' Graz",
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '7/8/2016',
#   'Location': 'Austria'},
#  {'Name': 'Herräng Dance Camp week 2',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Other'],
#   'Date': '7/9/2016',
#   'Location': 'Sweden'},
#  {'Name': 'Rhythm Weekend: Omaha Tap Dance Festival ',
#   'Genre': ['Solo Jazz', 'Other'],
#   'Date': '7/14/2016',
#   'Location': 'USA'},
#  {'Name': 'Bristol Blues Exchange',
#   'Genre': ['Blues'],
#   'Date': '7/15/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'DJX Summertime',
#   'Genre': ['Fusion'],
#   'Date': '7/15/2016',
#   'Location': 'USA'},
#  {'Name': 'Kiel Lindy Exchange',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '7/15/2016',
#   'Location': 'Germany'},
#  {'Name': 'Herräng Dance Camp week 3',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Other'],
#   'Date': '7/16/2016',
#   'Location': 'Sweden'},
#  {'Name': 'KissME in Ann Arbor',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '7/22/2016',
#   'Location': 'USA'},
#  {'Name': 'Nocturne Blues',
#   'Genre': ['Blues'],
#   'Date': '7/22/2016',
#   'Location': 'USA'},
#  {'Name': 'The Process',
#   'Genre': ['Lindy'],
#   'Date': '7/22/2016',
#   'Location': 'USA'},
#  {'Name': 'Herräng Dance Camp week 4',
#   'Genre': ['Lindy', 'Solo Jazz', 'Other'],
#   'Date': '7/23/2016',
#   'Location': 'Sweden'},
#  {'Name': 'Canberräng',
#   'Genre': ['Blues', 'Lindy', 'Balboa'],
#   'Date': '7/28/2016',
#   'Location': 'Australia'},
#  {'Name': 'Sweet Molasses Blues',
#   'Genre': ['Blues'],
#   'Date': '7/29/2016',
#   'Location': 'USA'},
#  {'Name': 'Herräng Dance Camp week 5',
#   'Genre': ['Lindy', 'Solo Jazz', 'Other'],
#   'Date': '7/30/2016',
#   'Location': 'Sweden'},
#  {'Name': 'Studio Hop Summer Camp : Blues week',
#   'Genre': ['Blues', 'Other'],
#   'Date': '7/30/2016',
#   'Location': 'France'},
#  {'Name': 'Summer Fusion Project',
#   'Genre': ['Fusion'],
#   'Date': '7/30/2016',
#   'Location': 'Canada'},
#  {'Name': 'Lindy on the Rocks',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '8/4/2016',
#   'Location': 'USA'},
#  {'Name': 'Sweet Molasses Blues Weeekend',
#   'Genre': ['Blues'],
#   'Date': '8/4/2016',
#   'Location': 'USA'},
#  {'Name': 'Bal-Ast Off!',
#   'Genre': ['Balboa'],
#   'Date': '8/5/2016',
#   'Location': 'USA'},
#  {'Name': 'Bristol Shag Fiesta - First International Collegiate Shag Exchange',
#   'Genre': ['Shag'],
#   'Date': '8/5/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'DJX + Dance Alchemy Fusion Weekend ',
#   'Genre': ['Fusion'],
#   'Date': '8/5/2016',
#   'Location': 'Canada'},
#  {'Name': 'Tobacco Road Blues Exchange',
#   'Genre': ['Blues'],
#   'Date': '8/5/2016',
#   'Location': 'USA'},
#  {'Name': 'Wellbourne Jazz Camp Week 1',
#   'Genre': ['Lindy', 'Solo Jazz', 'Other'],
#   'Date': '8/7/2016',
#   'Location': 'USA'},
#  {'Name': ' Swing Fling',
#   'Genre': ['West Coast'],
#   'Date': '8/11/2016',
#   'Location': 'USA'},
#  {'Name': 'Ceuvel Swing Camp 2016',
#   'Genre': ['Fusion'],
#   'Date': '8/12/2016',
#   'Location': 'Netherlands'},
#  {'Name': 'CincyHop',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '8/12/2016',
#   'Location': 'USA'},
#  {'Name': 'Seattle Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '8/12/2016',
#   'Location': 'USA'},
#  {'Name': 'Sweet Georgia Blues 2016',
#   'Genre': ['Blues', 'Other'],
#   'Date': '8/12/2016',
#   'Location': 'USA'},
#  {'Name': 'The Loco Chihuahua Lindy Challenge',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz'],
#   'Date': '8/12/2016',
#   'Location': 'Mexico'},
#  {'Name': 'Festival Alan Swing',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'West Coast'],
#   'Date': '8/13/2016',
#   'Location': 'France'},
#  {'Name': 'Arctic Lindy Exchange',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '8/14/2016',
#   'Location': 'Iceland'},
#  {'Name': 'Wellbourne Jazz Camp Week 2',
#   'Genre': ['Lindy', 'Solo Jazz', 'Other'],
#   'Date': '8/17/2016',
#   'Location': 'USA'},
#  {'Name': 'Northwest Alt-Blues Recess',
#   'Genre': ['Fusion'],
#   'Date': '8/18/2016',
#   'Location': 'USA'},
#  {'Name': 'Northwest Recess 2016',
#   'Genre': ['Fusion'],
#   'Date': '8/18/2016',
#   'Location': 'USA'},
#  {'Name': 'Albany Lindy & Blues & Swimming',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '8/19/2016',
#   'Location': 'USA'},
#  {'Name': 'Great Lakes Balboa Escape',
#   'Genre': ['Balboa'],
#   'Date': '8/19/2016',
#   'Location': 'USA'},
#  {'Name': 'Hummingbird Blues',
#   'Genre': ['Blues'],
#   'Date': '8/19/2016',
#   'Location': 'Poland'},
#  {'Name': 'Twilight Blues & Fusion',
#   'Genre': ['Fusion'],
#   'Date': '8/19/2016',
#   'Location': 'Netherlands'},
#  {'Name': 'Lindy In The Park 20th Anniversary!',
#   'Genre': ['Lindy'],
#   'Date': '8/20/2016',
#   'Location': 'USA'},
#  {'Name': 'International Lindy Hop Championships',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '8/25/2016',
#   'Location': 'USA'},
#  {'Name': 'Summer Hummer',
#   'Genre': ['West Coast'],
#   'Date': '8/25/2016',
#   'Location': 'USA'},
#  {'Name': 'LexSwing Dance Fall Workshop',
#   'Genre': ['Lindy'],
#   'Date': '8/27/2016',
#   'Location': 'USA'},
#  {'Name': 'Swinging August Nights',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '8/27/2016',
#   'Location': 'USA'},
#  {'Name': 'Swing Out New Hampshire',
#   'Genre': ['Blues', 'Lindy', 'Balboa'],
#   'Date': '8/31/2016',
#   'Location': 'USA'},
#  {'Name': '1st Open Blues',
#   'Genre': ['Fusion'],
#   'Date': '9/1/2016',
#   'Location': 'Poland'},
#  {'Name': 'I Heart Balboa',
#   'Genre': ['Balboa'],
#   'Date': '9/2/2016',
#   'Location': 'USA'},
#  {'Name': 'Octoblues',
#   'Genre': ['Blues'],
#   'Date': '9/2/2016',
#   'Location': 'Germany'},
#  {'Name': 'Pensacola Blues Exchange',
#   'Genre': ['Blues'],
#   'Date': '9/2/2016',
#   'Location': 'USA'},
#  {'Name': 'SwingIN ',
#   'Genre': ['Lindy'],
#   'Date': '9/2/2016',
#   'Location': 'USA'},
#  {'Name': 'Dirt Cheap Blues 2016',
#   'Genre': ['Blues'],
#   'Date': '9/8/2016',
#   'Location': 'USA'},
#  {'Name': 'bay area micro fusion',
#   'Genre': ['Fusion'],
#   'Date': '9/9/2016',
#   'Location': 'USA'},
#  {'Name': 'Blues Yourself',
#   'Genre': ['Blues', 'Solo Jazz'],
#   'Date': '9/9/2016',
#   'Location': 'USA'},
#  {'Name': 'Cowtown Jamborama',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '9/9/2016',
#   'Location': 'USA'},
#  {'Name': 'High Sierra Recess Massive',
#   'Genre': ['Fusion'],
#   'Date': '9/12/2016',
#   'Location': 'USA'},
#  {'Name': 'Recess Massive: High Sierras Edition',
#   'Genre': ['Fusion'],
#   'Date': '9/12/2016',
#   'Location': 'USA'},
#  {'Name': 'Classic City Swing',
#   'Genre': ['Lindy'],
#   'Date': '9/16/2016',
#   'Location': 'USA'},
#  {'Name': 'Edinburgh Lindy Exchange',
#   'Genre': ['Blues', 'Lindy', 'Balboa'],
#   'Date': '9/16/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'North Star Blues',
#   'Genre': ['Blues'],
#   'Date': '9/16/2016',
#   'Location': 'USA'},
#  {'Name': 'Rhythm Shuffle',
#   'Genre': ['Balboa'],
#   'Date': '9/16/2016',
#   'Location': 'USA'},
#  {'Name': 'Xpress Your Swing',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '9/16/2016',
#   'Location': 'France'},
#  {'Name': 'Seattle Fusion Festival',
#   'Genre': ['Fusion'],
#   'Date': '9/22/2016',
#   'Location': 'USA'},
#  {'Name': 'Blues Exchange @ Toulouse',
#   'Genre': ['Fusion'],
#   'Date': '9/23/2016',
#   'Location': 'France'},
#  {'Name': 'Cotton City Blues 2016',
#   'Genre': ['Blues'],
#   'Date': '9/23/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'Dance St. Lou Blue 2016',
#   'Genre': ['Blues'],
#   'Date': '9/23/2016',
#   'Location': 'USA'},
#  {'Name': 'Lindyworks',
#   'Genre': ['Lindy'],
#   'Date': '9/23/2016',
#   'Location': 'Canada'},
#  {'Name': 'PSDS Sweet 16 Workshop',
#   'Genre': ['Lindy'],
#   'Date': '9/23/2016',
#   'Location': 'USA'},
#  {'Name': 'Balboa on the River 2016 ',
#   'Genre': ['Balboa'],
#   'Date': '9/29/2016',
#   'Location': 'Australia'},
#  {'Name': 'The World Jam',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '9/29/2016',
#   'Location': 'Spain'},
#  {'Name': 'Blues n Soul 4',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '9/30/2016',
#   'Location': 'USA'},
#  {'Name': 'Copenhagen Swing Challenge',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '9/30/2016',
#   'Location': 'Denmark'},
#  {'Name': 'Lonestar Strut',
#   'Genre': ['Blues'],
#   'Date': '9/30/2016',
#   'Location': 'USA'},
#  {'Name': 'Moscow Jazz Weekend',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz'],
#   'Date': '9/30/2016',
#   'Location': 'Russia'},
#  {'Name': 'TinkerBal',
#   'Genre': ['Balboa'],
#   'Date': '9/30/2016',
#   'Location': 'USA'},
#  {'Name': 'Mallorca Lindy Festival',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '10/6/2016',
#   'Location': 'Spain'},
#  {'Name': 'Bring Your Own Blues Experience',
#   'Genre': ['Blues'],
#   'Date': '10/7/2016',
#   'Location': 'USA'},
#  {'Name': 'Mean Old Blues',
#   'Genre': ['Blues'],
#   'Date': '10/7/2016',
#   'Location': 'USA'},
#  {'Name': 'Berlin Blues Immersion – A DanceMode Experience',
#   'Genre': ['Blues'],
#   'Date': '10/11/2016',
#   'Location': 'Germany'},
#  {'Name': 'Balboa Cologne',
#   'Genre': ['Balboa'],
#   'Date': '10/14/2016',
#   'Location': 'Germany'},
#  {'Name': "Jammin' on the James",
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '10/14/2016',
#   'Location': 'USA'},
#  {'Name': 'Nitty Gritty Blues',
#   'Genre': ['Blues'],
#   'Date': '10/14/2016',
#   'Location': 'United Kingdom'},
#  {'Name': 'Slow Dance Soirée',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '10/14/2016',
#   'Location': 'USA'},
#  {'Name': 'Slowdown ',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '10/14/2016',
#   'Location': 'Australia'},
#  {'Name': 'Drag the blues 16',
#   'Genre': ['Fusion'],
#   'Date': '10/20/2016',
#   'Location': 'Spain'},
#  {'Name': 'Blues Muse 2016',
#   'Genre': ['Blues'],
#   'Date': '10/21/2016',
#   'Location': 'USA'},
#  {'Name': 'Knoxville Lindy Exchange 16th Annual!!',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '10/21/2016',
#   'Location': 'USA'},
#  {'Name': 'Rocky Mountain Balboa Blowout',
#   'Genre': ['Balboa'],
#   'Date': '10/21/2016',
#   'Location': 'USA'},
#  {'Name': 'Swing Pittsburgh',
#   'Genre': ['West Coast'],
#   'Date': '10/27/2016',
#   'Location': 'USA'},
#  {'Name': '2016 Championships',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Other'],
#   'Date': '10/28/2016',
#   'Location': 'USA'},
#  {'Name': '2o LINDYFEST CHILE 2016',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz', 'Shag'],
#   'Date': '10/28/2016',
#   'Location': 'Chile'},
#  {'Name': 'Atlanta Varsity Showdown 2016',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '10/28/2016',
#   'Location': 'USA'},
#  {'Name': 'Barcelona Shag Festival',
#   'Genre': ['Shag'],
#   'Date': '10/28/2016',
#   'Location': 'Spain'},
#  {'Name': 'Elm City Exchange',
#   'Genre': ['Fusion'],
#   'Date': '10/28/2016',
#   'Location': 'USA'},
#  {'Name': 'Lindy Shock University',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '10/28/2016',
#   'Location': 'Hungary'},
#  {'Name': 'Sicily Swing Fest',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '11/3/2016',
#   'Location': 'Italy'},
#  {'Name': 'Capital City Swing Jam',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '11/4/2016',
#   'Location': 'USA'},
#  {'Name': 'Phoenix Lindy Exchange 16',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '11/4/2016',
#   'Location': 'USA'},
#  {'Name': 'Rose City Blues',
#   'Genre': ['Blues'],
#   'Date': '11/4/2016',
#   'Location': 'USA'},
#  {'Name': 'Swing Aus',
#   'Genre': ['Lindy'],
#   'Date': '11/4/2016',
#   'Location': 'USA'},
#  {'Name': 'ROCkabilly Hop II',
#   'Genre': ['Boogie Woogie', 'Other'],
#   'Date': '11/5/2016',
#   'Location': 'USA'},
#  {'Name': 'Holy City Blues VII',
#   'Genre': ['Blues'],
#   'Date': '11/10/2016',
#   'Location': 'USA'},
#  {'Name': 'DJX November Workshop Weekend',
#   'Genre': ['Fusion'],
#   'Date': '11/11/2016',
#   'Location': 'USA'},
#  {'Name': 'Lindy Hop on the Plains 4',
#   'Genre': ['Lindy'],
#   'Date': '11/11/2016',
#   'Location': 'USA'},
#  {'Name': 'The Revival',
#   'Genre': ['Balboa', 'Shag'],
#   'Date': '11/11/2016',
#   'Location': 'Sweden'},
#  {'Name': '17th Annual Austin Lindy Exchange',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Shag', 'West Coast'],
#   'Date': '11/17/2016',
#   'Location': 'USA'},
#  {'Name': 'Floor Divided 2016',
#   'Genre': ['Lindy'],
#   'Date': '11/18/2016',
#   'Location': 'USA'},
#  {'Name': 'MMMBlues Exchange',
#   'Genre': ['Blues'],
#   'Date': '11/18/2016',
#   'Location': 'Canada'},
#  {'Name': 'PittStop Lindy Hop 16',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '11/18/2016',
#   'Location': 'USA'},
#  {'Name': 'East Side Blues 2016',
#   'Genre': ['Blues'],
#   'Date': '11/19/2016',
#   'Location': 'Malaysia'},
#  {'Name': 'Cold Moon Bal 2016',
#   'Genre': ['Balboa'],
#   'Date': '12/2/2016',
#   'Location': 'Poland'},
#  {'Name': 'Snowbound Blues',
#   'Genre': ['Blues'],
#   'Date': '12/2/2016',
#   'Location': 'USA'},
#  {'Name': 'Midnight in Paris Winter Formal',
#   'Genre': ['Fusion'],
#   'Date': '12/8/2016',
#   'Location': 'USA'},
#  {'Name': 'South Bay Traditional Jazz Society',
#   'Genre': ['Fusion'],
#   'Date': '12/18/2016',
#   'Location': 'USA'},
#  {'Name': 'Lindy Focus XV 2016',
#   'Genre': ['Lindy'],
#   'Date': '12/26/2016',
#   'Location': 'USA'},
#  {'Name': 'Moscow Christmas Swing Dance Camp',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'Boogie Woogie'],
#   'Date': '1/3/2017',
#   'Location': 'Russia'},
#  {'Name': 'California Balboa Classic',
#   'Genre': ['Balboa'],
#   'Date': '1/6/2017',
#   'Location': 'USA'},
#  {'Name': 'City In Motion San Diego',
#   'Genre': ['Fusion'],
#   'Date': '1/6/2017',
#   'Location': 'USA'},
#  {'Name': 'Hülly Hop Swing Farm 2017',
#   'Genre': ['Lindy'],
#   'Date': '1/6/2017',
#   'Location': 'Germany'},
#  {'Name': 'Monterey SwingFest',
#   'Genre': ['West Coast'],
#   'Date': '1/11/2017',
#   'Location': 'USA'},
#  {'Name': 'Lindy Hops The Atlantic',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '1/12/2017',
#   'Location': 'Denmark'},
#  {'Name': 'Dark Blue Swing Exchange',
#   'Genre': ['Lindy'],
#   'Date': '1/13/2017',
#   'Location': 'Czech Republic'},
#  {'Name': 'Freedom Swing',
#   'Genre': ['West Coast'],
#   'Date': '1/13/2017',
#   'Location': 'USA'},
#  {'Name': 'Hong Kong Swing Festival',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '1/13/2017',
#   'Location': 'Hong Kong'},
#  {'Name': 'My Lindy Kraze',
#   'Genre': ['Lindy'],
#   'Date': '1/13/2017',
#   'Location': 'USA'},
#  {'Name': 'Swing Camp Oz',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '1/13/2017',
#   'Location': 'Australia'},
#  {'Name': 'Blues workshop with Annette and Rufus',
#   'Genre': ['Blues'],
#   'Date': '1/14/2017',
#   'Location': 'Belgium'},
#  {'Name': 'Seastar BLUES Festival 2017',
#   'Genre': ['Fusion'],
#   'Date': '1/14/2017',
#   'Location': 'Jamaica'},
#  {'Name': 'Swing Mood Fest 2017',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '1/19/2017',
#   'Location': 'Spain'},
#  {'Name': 'Blues with Friends 2016',
#   'Genre': ['Blues'],
#   'Date': '1/20/2017',
#   'Location': 'USA'},
#  {'Name': 'Kind of a Big Deal Weekend',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '1/20/2017',
#   'Location': 'USA'},
#  {'Name': 'Jennifer Barnett Orlando Balboa Workshop',
#   'Genre': ['Balboa'],
#   'Date': '1/21/2017',
#   'Location': 'USA'},
#  {'Name': 'Balboa Dayz 2017',
#   'Genre': ['Balboa'],
#   'Date': '1/27/2017',
#   'Location': 'Germany'},
#  {'Name': 'Breizh Blues Invasion',
#   'Genre': ['Blues'],
#   'Date': '1/27/2017',
#   'Location': 'France'},
#  {'Name': 'Emerald City Solo Jam',
#   'Genre': ['Solo Jazz'],
#   'Date': '1/27/2017',
#   'Location': 'USA'},
#  {'Name': 'Gender Bender 2017 Recess',
#   'Genre': ['Fusion'],
#   'Date': '1/27/2017',
#   'Location': 'USA'},
#  {'Name': 'Hot Rhythm Holiday',
#   'Genre': ['Lindy', 'Balboa', 'Shag'],
#   'Date': '1/27/2017',
#   'Location': 'USA'},
#  {'Name': 'L.A. Blues 2017',
#   'Genre': ['Blues'],
#   'Date': '1/27/2017',
#   'Location': 'USA'},
#  {'Name': 'Lollies and Lemonade',
#   'Genre': ['Balboa'],
#   'Date': '1/27/2017',
#   'Location': 'USA'},
#  {'Name': 'Saint City Fusion: The Intro',
#   'Genre': ['Fusion'],
#   'Date': '1/27/2017',
#   'Location': 'USA'},
#  {'Name': 'South Florida Lindy Exchange',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '1/27/2017',
#   'Location': 'USA'},
#  {'Name': 'SEA Jam 2017',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/1/2017',
#   'Location': 'Singapore'},
#  {'Name': 'Black Coffee Blues Exchange',
#   'Genre': ['Blues'],
#   'Date': '2/3/2017',
#   'Location': 'Israel'},
#  {'Name': 'Double Shot of Blues & Fusion ',
#   'Genre': ['Fusion'],
#   'Date': '2/3/2017',
#   'Location': 'Spain'},
#  {'Name': 'FUSE 2017 - fusion & blues',
#   'Genre': ['Blues', 'West Coast'],
#   'Date': '2/3/2017',
#   'Location': 'USA'},
#  {'Name': 'Sparx',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '2/3/2017',
#   'Location': 'USA'},
#  {'Name': 'Salsa and Bachata Dance Cruise 2017',
#   'Genre': ['Other'],
#   'Date': '2/4/2017',
#   'Location': 'USA'},
#  {'Name': 'ATLANTIC BLUES',
#   'Genre': ['Blues'],
#   'Date': '2/9/2017',
#   'Location': 'Portugal'},
#  {'Name': 'Lindy Diversion 2017',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz'],
#   'Date': '2/10/2017',
#   'Location': 'USA'},
#  {'Name': 'Shamrock Swing',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/10/2017',
#   'Location': 'USA'},
#  {'Name': 'Sweet Swingouts Workshop',
#   'Genre': ['Lindy'],
#   'Date': '2/10/2017',
#   'Location': 'USA'},
#  {'Name': "Valentine's Blues",
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '2/10/2017',
#   'Location': 'Poland'},
#  {'Name': 'Whip-Ma-Whop-Ma-Hop',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/10/2017',
#   'Location': 'United Kingdom'},
#  {'Name': "Big City Blues Workshop ✯ A Fool's Paradise ✯",
#   'Genre': ['Blues'],
#   'Date': '2/11/2017',
#   'Location': 'Belgium'},
#  {'Name': 'Lindy Snacks 2017',
#   'Genre': ['Lindy'],
#   'Date': '2/11/2017',
#   'Location': 'Germany'},
#  {'Name': 'Rincon Fusion Rxion 2.0',
#   'Genre': ['Fusion'],
#   'Date': '2/16/2017',
#   'Location': 'Puerto Rico'},
#  {'Name': 'Crash! the Blues Festival Delft 2017',
#   'Genre': ['Blues'],
#   'Date': '2/17/2017',
#   'Location': 'Netherlands'},
#  {'Name': 'Lindylicious',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/17/2017',
#   'Location': 'France'},
#  {'Name': "Mo' Better Blues 2017",
#   'Genre': ['Blues'],
#   'Date': '2/17/2017',
#   'Location': 'USA'},
#  {'Name': 'Salt Lake Lindy Con',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/17/2017',
#   'Location': 'USA'},
#  {'Name': 'Seattle Social Blues Weekend',
#   'Genre': ['Blues'],
#   'Date': '2/17/2017',
#   'Location': 'USA'},
#  {'Name': 'A Taste of Boogie 2.0',
#   'Genre': ['Boogie Woogie'],
#   'Date': '2/18/2017',
#   'Location': 'Italy'},
#  {'Name': 'Fusion Project 3.0',
#   'Genre': ['Fusion'],
#   'Date': '2/18/2017',
#   'Location': 'Canada'},
#  {'Name': 'Rock That Swing Festival',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Boogie Woogie'],
#   'Date': '2/23/2017',
#   'Location': 'Germany'},
#  {'Name': 'Rose City Swing',
#   'Genre': ['West Coast'],
#   'Date': '2/23/2017',
#   'Location': 'USA'},
#  {'Name': 'Balboa Snacks',
#   'Genre': ['Balboa'],
#   'Date': '2/24/2017',
#   'Location': 'Germany'},
#  {'Name': 'LabLove 2017',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '2/24/2017',
#   'Location': 'USA'},
#  {'Name': 'Ljubljana Blues Exchange',
#   'Genre': ['Blues'],
#   'Date': '2/24/2017',
#   'Location': 'Slovenia'},
#  {'Name': 'London Jump Solo Jazz',
#   'Genre': ['Solo Jazz'],
#   'Date': '2/24/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Oxford Swing Festival',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '2/24/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Roma Balboa & Shag Exchange - 2nd',
#   'Genre': ['Balboa', 'Shag'],
#   'Date': '2/24/2017',
#   'Location': 'Italy'},
#  {'Name': 'Saltwater Blues',
#   'Genre': ['Blues'],
#   'Date': '2/24/2017',
#   'Location': 'Canada'},
#  {'Name': 'Four on the Floor Workshop Weekend',
#   'Genre': ['Balboa'],
#   'Date': '2/25/2017',
#   'Location': 'USA'},
#  {'Name': 'Berlin Balboa Weekend',
#   'Genre': ['Balboa'],
#   'Date': '3/2/2017',
#   'Location': 'Germany'},
#  {'Name': 'MADjam',
#   'Genre': ['West Coast'],
#   'Date': '3/2/2017',
#   'Location': 'USA'},
#  {'Name': 'Austin Blues Party X',
#   'Genre': ['Blues'],
#   'Date': '3/3/2017',
#   'Location': 'USA'},
#  {'Name': 'Brown ALe Blues 2017',
#   'Genre': ['Fusion'],
#   'Date': '3/3/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Inspiration Weekend',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '3/3/2017',
#   'Location': 'USA'},
#  {'Name': 'Orlando Lindy Exchange X: Achievement Unlocked',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '3/3/2017',
#   'Location': 'USA'},
#  {'Name': 'Retro Weekend Festival',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '3/3/2017',
#   'Location': 'Poland'},
#  {'Name': 'Solo Mojo 2017',
#   'Genre': ['Solo Jazz'],
#   'Date': '3/3/2017',
#   'Location': 'Singapore'},
#  {'Name': 'The Madison Invasion 2017',
#   'Genre': ['Lindy'],
#   'Date': '3/3/2017',
#   'Location': 'USA'},
#  {'Name': 'Vietnam Lindy Exchange',
#   'Genre': ['Lindy'],
#   'Date': '3/3/2017',
#   'Location': 'Vietnam'},
#  {'Name': 'Swing Break Mexico 2017',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '3/6/2017',
#   'Location': 'Mexico'},
#  {'Name': "Cruisin' for a Bluesin' 2017",
#   'Genre': ['Fusion'],
#   'Date': '3/9/2017',
#   'Location': 'USA'},
#  {'Name': 'BadAZ Balboa',
#   'Genre': ['Balboa'],
#   'Date': '3/10/2017',
#   'Location': 'USA'},
#  {'Name': 'O-Town Showdown',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '3/10/2017',
#   'Location': 'Canada'},
#  {'Name': 'Pirate Swing',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz'],
#   'Date': '3/10/2017',
#   'Location': 'USA'},
#  {'Name': 'The Blues Garden',
#   'Genre': ['Blues'],
#   'Date': '3/10/2017',
#   'Location': 'Sweden'},
#  {'Name': 'Lucky Skillen at Auld Reekie Blues',
#   'Genre': ['Blues'],
#   'Date': '3/11/2017',
#   'Location': 'Great Britain'},
#  {'Name': 'Mozambique Afro Swing Exchange',
#   'Genre': ['Fusion'],
#   'Date': '3/13/2017',
#   'Location': 'Mozambique'},
#  {'Name': 'COCOA Blues Exchange (Barcelona)',
#   'Genre': ['Blues'],
#   'Date': '3/16/2017',
#   'Location': 'Spain'},
#  {'Name': 'Lindyfest & Lone Star Championships',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '3/16/2017',
#   'Location': 'USA'},
#  {'Name': 'Come Around Montreal',
#   'Genre': ['Balboa'],
#   'Date': '3/17/2017',
#   'Location': 'Canada'},
#  {'Name': 'Jens Rahnfeld',
#   'Genre': ['Solo Jazz'],
#   'Date': '3/17/2017',
#   'Location': 'Germany'},
#  {'Name': 'Music City Exchange',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '3/17/2017',
# ...
#   'Genre': ['Blues'],
#   'Date': '6/30/2017',
#   'Location': 'USA'},
#  {'Name': 'Herrang Dance Camp Week 1',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'Boogie Woogie'],
#   'Date': '7/1/2017',
#   'Location': 'Sweden'},
#  {'Name': 'Dancing the Blues Pistoia, Tuscany',
#   'Genre': ['Blues'],
#   'Date': '7/6/2017',
#   'Location': 'Italy'},
#  {'Name': 'Blue Infusion Goes Red and Weismann',
#   'Genre': ['Fusion'],
#   'Date': '7/7/2017',
#   'Location': 'Canada'},
#  {'Name': 'River City Mess Around',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '7/7/2017',
#   'Location': 'USA'},
#  {'Name': 'San Diego Balboa & Lindy Exchange',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '7/7/2017',
#   'Location': 'USA'},
#  {'Name': 'Swing in Corsica',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '7/7/2017',
#   'Location': 'France'},
#  {'Name': 'The Blues Spot',
#   'Genre': ['Blues', 'Solo Jazz'],
#   'Date': '7/7/2017',
#   'Location': 'France'},
#  {'Name': 'Twilight Blues & Fusion Amsterdam',
#   'Genre': ['Fusion'],
#   'Date': '7/7/2017',
#   'Location': 'Netherlands'},
#  {'Name': 'Fuze-On Tampa Bay Presents: Revolution Fusion!',
#   'Genre': ['Fusion'],
#   'Date': '7/8/2017',
#   'Location': 'USA'},
#  {'Name': 'Herrang Dance Camp Week 2',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'Boogie Woogie'],
#   'Date': '7/8/2017',
#   'Location': 'Sweden'},
#  {'Name': 'The Spoonful',
#   'Genre': ['Blues'],
#   'Date': '7/13/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Albany Lindy & Blues & Swimming',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '7/14/2017',
#   'Location': 'USA'},
#  {'Name': 'Chorus Girl University',
#   'Genre': ['Solo Jazz'],
#   'Date': '7/14/2017',
#   'Location': 'USA'},
#  {'Name': 'Disco Ball Dance Party Summer Retreat',
#   'Genre': ['Fusion'],
#   'Date': '7/15/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Herrang Dance Camp Week 3',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'Boogie Woogie'],
#   'Date': '7/15/2017',
#   'Location': 'Sweden'},
#  {'Name': 'No School Like the Old School Workshop Weekend',
#   'Genre': ['Balboa'],
#   'Date': '7/15/2017',
#   'Location': 'USA'},
#  {'Name': 'Lucerne Blues/Swing Immersion',
#   'Genre': ['Blues', 'Lindy', 'Other'],
#   'Date': '7/17/2017',
#   'Location': 'Switzerland'},
#  {'Name': 'SUMMER BLUES CAMP',
#   'Genre': ['Blues'],
#   'Date': '7/17/2017',
#   'Location': 'Switzerland'},
#  {'Name': 'Hamburg Balboa Exchange',
#   'Genre': ['Fusion'],
#   'Date': '7/20/2017',
#   'Location': 'Germany'},
#  {'Name': 'Shakori Hills Recess',
#   'Genre': ['Fusion'],
#   'Date': '7/20/2017',
#   'Location': 'USA'},
#  {'Name': 'Fusion Inclusion Campout',
#   'Genre': ['Fusion'],
#   'Date': '7/21/2017',
#   'Location': 'USA'},
#  {'Name': 'Greenville Lindy Exchange 7',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '7/21/2017',
#   'Location': 'USA'},
#  {'Name': 'The Process',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '7/21/2017',
#   'Location': 'USA'},
#  {'Name': 'Herrang Dance Camp Week 4',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'Boogie Woogie'],
#   'Date': '7/22/2017',
#   'Location': 'Sweden'},
#  {'Name': "MezzJelly Blues '17 :: NYC :: 18th Anniversary",
#   'Genre': ['Blues'],
#   'Date': '7/28/2017',
#   'Location': 'USA'},
#  {'Name': 'Herrang Dance Camp Week 5',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag', 'Boogie Woogie'],
#   'Date': '7/29/2017',
#   'Location': 'Sweden'},
#  {'Name': 'Aspen Recess',
#   'Genre': ['Fusion'],
#   'Date': '8/3/2017',
#   'Location': 'USA'},
#  {'Name': 'Blues/Jazz Dance Immersion',
#   'Genre': ['Blues'],
#   'Date': '8/3/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Canberräng 2017',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Shag'],
#   'Date': '8/3/2017',
#   'Location': 'Australia'},
#  {'Name': 'Balast Off!',
#   'Genre': ['Balboa'],
#   'Date': '8/4/2017',
#   'Location': 'USA'},
#  {'Name': 'Sweet Molasses Blues',
#   'Genre': ['Blues'],
#   'Date': '8/4/2017',
#   'Location': 'USA'},
#  {'Name': 'TURQUOISE 2017',
#   'Genre': ['Fusion'],
#   'Date': '8/4/2017',
#   'Location': 'USA'},
#  {'Name': 'Blues/Jazz Dance Workshop',
#   'Genre': ['Blues'],
#   'Date': '8/5/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Mountain Blues Camp',
#   'Genre': ['Blues'],
#   'Date': '8/6/2017',
#   'Location': 'France'},
#  {'Name': 'Northwest Recess',
#   'Genre': ['Fusion'],
#   'Date': '8/10/2017',
#   'Location': 'USA'},
#  {'Name': 'CincyHop 2017',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '8/11/2017',
#   'Location': 'USA'},
#  {'Name': 'Hummingbird Blues 2017',
#   'Genre': ['Fusion'],
#   'Date': '8/11/2017',
#   'Location': 'Poland'},
#  {'Name': 'Uptown Swingout 2017',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '8/11/2017',
#   'Location': 'USA'},
#  {'Name': 'Amber Swing ',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '8/17/2017',
#   'Location': 'Poland'},
#  {'Name': 'Ceuvel Swing Camp 2016',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz'],
#   'Date': '8/17/2017',
#   'Location': 'Netherlands'},
#  {'Name': 'Bay Area Micro Fusion 2017',
#   'Genre': ['Fusion'],
#   'Date': '8/18/2017',
#   'Location': 'USA'},
#  {'Name': 'Bluesila',
#   'Genre': ['Blues'],
#   'Date': '8/18/2017',
#   'Location': 'Lithuania'},
#  {'Name': 'Great Lakes Balboa Escape 2017',
#   'Genre': ['Balboa'],
#   'Date': '8/18/2017',
#   'Location': 'USA'},
#  {'Name': 'Lindy 500',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '8/18/2017',
#   'Location': 'USA'},
#  {'Name': 'Summer Bal 2017 with Solen & Laurent',
#   'Genre': ['Balboa'],
#   'Date': '8/19/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'International Lindy Hop Championships',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Other'],
#   'Date': '8/24/2017',
#   'Location': 'USA'},
#  {'Name': 'Bear Blues Exchange',
#   'Genre': ['Blues'],
#   'Date': '8/25/2017',
#   'Location': 'Germany'},
#  {'Name': 'Leeds Swing Exchange',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Shag'],
#   'Date': '8/25/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Southbound Blues Exchange Vol. II',
#   'Genre': ['Blues'],
#   'Date': '8/25/2017',
#   'Location': 'USA'},
#  {'Name': 'The Rigamarole',
#   'Genre': ['Balboa'],
#   'Date': '8/25/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Swing Out New Hampshire',
#   'Genre': ['Blues', 'Lindy', 'Balboa'],
#   'Date': '8/30/2017',
#   'Location': 'USA'},
#  {'Name': 'Open Blues 2017',
#   'Genre': ['Fusion'],
#   'Date': '8/31/2017',
#   'Location': 'Poland'},
#  {'Name': 'Camp Blues Santa Cruz',
#   'Genre': ['Blues', 'Other'],
#   'Date': '9/1/2017',
#   'Location': 'USA'},
#  {'Name': 'Hamburg Lindy Exchange 2017',
#   'Genre': ['Lindy', 'Balboa', 'Shag'],
#   'Date': '9/1/2017',
#   'Location': 'Germany'},
#  {'Name': 'I Heart Balboa',
#   'Genre': ['Balboa'],
#   'Date': '9/1/2017',
#   'Location': 'USA'},
#  {'Name': 'Oslo Balboa Weekend',
#   'Genre': ['Balboa'],
#   'Date': '9/1/2017',
#   'Location': 'Norway'},
#  {'Name': 'Dirt Cheap Blues',
#   'Genre': ['Blues'],
#   'Date': '9/7/2017',
#   'Location': 'USA'},
#  {'Name': 'BE-Bluesed',
#   'Genre': ['Blues'],
#   'Date': '9/8/2017',
#   'Location': 'Switzerland'},
#  {'Name': 'Blues River Notes - The Festival',
#   'Genre': ['Blues'],
#   'Date': '9/8/2017',
#   'Location': 'Italy'},
#  {'Name': 'North Shore Dance Night',
#   'Genre': ['Blues'],
#   'Date': '9/9/2017',
#   'Location': 'USA'},
#  {'Name': 'North Star Blues',
#   'Genre': ['Blues'],
#   'Date': '9/14/2017',
#   'Location': 'USA'},
#  {'Name': '4th Line Dance Festival LINERAfest 2017',
#   'Genre': ['Other'],
#   'Date': '9/15/2017',
#   'Location': 'Slovenia'},
#  {'Name': 'CPH Fusion Festival ',
#   'Genre': ['Fusion'],
#   'Date': '9/15/2017',
#   'Location': 'Denmark'},
#  {'Name': 'Hot Night Fusion Weekend',
#   'Genre': ['Fusion'],
#   'Date': '9/15/2017',
#   'Location': 'USA'},
#  {'Name': 'Lindy on the Rocks',
#   'Genre': ['Fusion'],
#   'Date': '9/15/2017',
#   'Location': 'USA'},
#  {'Name': 'Octoblues',
#   'Genre': ['Blues'],
#   'Date': '9/15/2017',
#   'Location': 'Germany'},
#  {'Name': 'Rhythm Shuffle',
#   'Genre': ['Balboa'],
#   'Date': '9/15/2017',
#   'Location': 'USA'},
#  {'Name': 'Dirty Water Lindy Exchange',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '9/21/2017',
#   'Location': 'USA'},
#  {'Name': 'Blues Exchange In Toulouse',
#   'Genre': ['Fusion'],
#   'Date': '9/22/2017',
#   'Location': 'France'},
#  {'Name': 'Cotton City Blues',
#   'Genre': ['Blues'],
#   'Date': '9/22/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Harvest Moon Weekend',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '9/22/2017',
#   'Location': 'USA'},
#  {'Name': 'Lindy Hop on the Plains 5',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '9/22/2017',
#   'Location': 'USA'},
#  {'Name': 'Lindy Works',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '9/22/2017',
#   'Location': 'Canada'},
#  {'Name': 'Lindyworks',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '9/22/2017',
#   'Location': 'Canada'},
#  {'Name': "Shaggin' Montreal 2017",
#   'Genre': ['Balboa', 'Shag'],
#   'Date': '9/22/2017',
#   'Location': 'Canada'},
#  {'Name': 'SwingIN 2017',
#   'Genre': ['Lindy', 'Solo Jazz', 'Shag'],
#   'Date': '9/22/2017',
#   'Location': 'USA'},
#  {'Name': 'The Cave of Blues',
#   'Genre': ['Blues'],
#   'Date': '9/22/2017',
#   'Location': 'Spain'},
#  {'Name': "IDW's Fusion Dance Mini-Weekender",
#   'Genre': ['Fusion'],
#   'Date': '9/23/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'The New Orleans Swing Dance Festival',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '9/28/2017',
#   'Location': 'USA'},
#  {'Name': 'Classic City Swing 6',
#   'Genre': ['Lindy'],
#   'Date': '9/29/2017',
#   'Location': 'USA'},
#  {'Name': 'Dance St. Lou Blue 2017',
#   'Genre': ['Blues'],
#   'Date': '9/29/2017',
#   'Location': 'USA'},
#  {'Name': 'Seattle Fusion festival',
#   'Genre': ['Fusion'],
#   'Date': '9/29/2017',
#   'Location': 'USA'},
#  {'Name': 'Suitcase Blues',
#   'Genre': ['Blues'],
#   'Date': '9/29/2017',
#   'Location': 'Spain'},
#  {'Name': 'TinkerBal 2017',
#   'Genre': ['Balboa'],
#   'Date': '9/30/2017',
#   'Location': 'USA'},
#  {'Name': 'Berlin Blues Explosion',
#   'Genre': ['Blues'],
#   'Date': '10/5/2017',
#   'Location': 'Germany'},
#  {'Name': 'Backwater Blues',
#   'Genre': ['Blues'],
#   'Date': '10/6/2017',
#   'Location': 'USA'},
#  {'Name': 'Balhalla Weekend',
#   'Genre': ['Balboa'],
#   'Date': '10/6/2017',
#   'Location': 'USA'},
#  {'Name': 'Blues n Soul 5',
#   'Genre': ['Fusion'],
#   'Date': '10/6/2017',
#   'Location': 'USA'},
#  {'Name': "Chapadas Folk'n Blues",
#   'Genre': ['Fusion'],
#   'Date': '10/6/2017',
#   'Location': 'Brazil'},
#  {'Name': 'Mean Old Blues 2017',
#   'Genre': ['Blues'],
#   'Date': '10/6/2017',
#   'Location': 'USA'},
#  {'Name': 'Moonshine Lindy & Blues',
#   'Genre': ['Blues', 'Lindy', 'Solo Jazz'],
#   'Date': '10/6/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Berlin Blues Immersion',
#   'Genre': ['Blues'],
#   'Date': '10/9/2017',
#   'Location': 'Germany'},
#  {'Name': 'Belta Blues 2017',
#   'Genre': ['Blues'],
#   'Date': '10/13/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Capital city swing jam',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '10/13/2017',
#   'Location': 'USA'},
#  {'Name': 'Cool Cat Corner V',
#   'Genre': ['Lindy'],
#   'Date': '10/13/2017',
#   'Location': 'USA'},
#  {'Name': 'Sundance Swing Out',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '10/13/2017',
#   'Location': 'USA'},
#  {'Name': 'Blues Muse 2017: 10th Anniversary!',
#   'Genre': ['Blues'],
#   'Date': '10/20/2017',
#   'Location': 'USA'},
#  {'Name': 'Drag the Blues',
#   'Genre': ['Blues'],
#   'Date': '10/20/2017',
#   'Location': 'Spain'},
#  {'Name': "Jammin' on the James",
#   'Genre': ['Lindy'],
#   'Date': '10/20/2017',
#   'Location': 'USA'},
#  {'Name': 'Rocky Mountain Balboa',
#   'Genre': ['Balboa'],
#   'Date': '10/20/2017',
#   'Location': 'USA'},
#  {'Name': 'Atlanta Varsity Showdown',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '10/27/2017',
#   'Location': 'USA'},
#  {'Name': 'CCX XIX 2017 - Lindy Blues & Balboa Exchange',
#   'Genre': ['Blues', 'Lindy', 'Balboa'],
#   'Date': '10/27/2017',
#   'Location': 'Canada'},
#  {'Name': 'Epic Fusion by BRB',
#   'Genre': ['Fusion'],
#   'Date': '10/27/2017',
#   'Location': 'USA'},
#  {'Name': 'Tokamak2017',
#   'Genre': ['Fusion'],
#   'Date': '10/27/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Cierra Ruffin Workshop Weekend',
#   'Genre': ['Blues'],
#   'Date': '10/28/2017',
#   'Location': 'USA'},
#  {'Name': 'Holy City Blues Exchange VIII',
#   'Genre': ['Blues'],
#   'Date': '11/2/2017',
#   'Location': 'USA'},
#  {'Name': 'Al-Andalblues Festival',
#   'Genre': ['Blues'],
#   'Date': '11/3/2017',
#   'Location': 'Spain'},
#  {'Name': 'Elm City Exchange ',
#   'Genre': ['Fusion'],
#   'Date': '11/3/2017',
#   'Location': 'USA'},
#  {'Name': 'INDIGO 2017',
#   'Genre': ['Fusion'],
#   'Date': '11/3/2017',
#   'Location': 'USA'},
#  {'Name': 'Lisbon Dance Mash Up',
#   'Genre': ['Blues', 'Balboa'],
#   'Date': '11/3/2017',
#   'Location': 'Portugal'},
#  {'Name': 'Rocky Balberna',
#   'Genre': ['Balboa'],
#   'Date': '11/3/2017',
#   'Location': 'Switzerland'},
#  {'Name': 'Rose City Blues',
#   'Genre': ['Blues'],
#   'Date': '11/3/2017',
#   'Location': 'USA'},
#  {'Name': 'Fog City Stomp',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '11/9/2017',
#   'Location': 'USA'},
#  {'Name': 'Fog City Stomp ',
#   'Genre': ['Lindy', 'Solo Jazz'],
#   'Date': '11/9/2017',
#   'Location': 'USA'},
#  {'Name': 'Blues in the Hudd 2017',
#   'Genre': ['Blues'],
#   'Date': '11/10/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'DJX November Workshop Weekend',
#   'Genre': ['Fusion'],
#   'Date': '11/10/2017',
#   'Location': 'USA'},
#  {'Name': 'Swingtoñal',
#   'Genre': ['Lindy', 'Balboa', 'Shag', 'Boogie Woogie'],
#   'Date': '11/10/2017',
#   'Location': 'Spain'},
#  {'Name': 'Austin Lindy Exchange ',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '11/16/2017',
#   'Location': 'USA'},
#  {'Name': 'Birmingham Swing Festival',
#   'Genre': ['Lindy', 'Balboa'],
#   'Date': '11/17/2017',
#   'Location': 'United Kingdom'},
#  {'Name': 'Karen and Dabney Swing Workshop',
#   'Genre': ['Lindy', 'Balboa', 'Shag'],
#   'Date': '11/17/2017',
#   'Location': 'USA'},
#  {'Name': 'Korea Balboa Weekend 2017 ',
#   'Genre': ['Balboa', 'Shag'],
#   'Date': '11/17/2017',
#   'Location': 'Korea South'},
#  {'Name': 'Lazy Blues',
#   'Genre': ['Blues'],
#   'Date': '11/17/2017',
#   'Location': 'Germany'},
#  {'Name': 'Montreal Blues Exchange',
#   'Genre': ['Blues'],
#   'Date': '11/17/2017',
#   'Location': 'Canada'},
#  {'Name': 'PittStop Lindy Hop',
#   'Genre': ['Lindy'],
#   'Date': '11/17/2017',
#   'Location': 'USA'},
#  {'Name': 'Sail City Jump!',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '11/17/2017',
#   'Location': 'New Zealand'},
#  {'Name': 'Whistle Stop 2017 (Purdue)',
#   'Genre': ['Lindy'],
#   'Date': '11/17/2017',
#   'Location': 'USA'},
#  {'Name': 'Blues Baby Blues',
#   'Genre': ['Blues'],
#   'Date': '11/24/2017',
#   'Location': 'Great Britain'},
#  {'Name': 'Isabella & Pontus Weekend 2017',
#   'Genre': ['Lindy', 'Solo Jazz', 'Boogie Woogie'],
#   'Date': '11/24/2017',
#   'Location': 'Germany'},
#  {'Name': 'Melbourne Lindy Exchange 2017',
#   'Genre': ['Blues', 'Lindy', 'Balboa', 'Solo Jazz', 'Shag'],
#   'Date': '11/30/2017',
#   'Location': 'Australia'},
#  {'Name': 'Petit ESBF',
#   'Genre': ['Blues'],
#   'Date': '12/1/2017',
#   'Location': 'Spain'},
#  {'Name': 'Bluesy Christmas with Jered & Zaza',
#   'Genre': ['Blues', 'Other'],
#   'Date': '12/8/2017',
#   'Location': 'France'},
#  {'Name': 'Snowbound Blues 2017',
#   'Genre': ['Blues'],
#   'Date': '12/8/2017',
#   'Location': 'USA'},
#  {'Name': 'Jingle Bal * 2017',
#   'Genre': ['Balboa'],
#   'Date': '12/9/2017',
#   'Location': 'USA'},
#  {'Name': 'Vienna Blues Weekend',
#   'Genre': ['Blues'],
#   'Date': '12/14/2017',
#   'Location': 'Austria'},
#  {'Name': 'Hub City Winter Exchange',
#   'Genre': ['Blues', 'Lindy'],
#   'Date': '12/15/2017',
#   'Location': 'USA'},
#  {'Name': 'Winter Wonderland Blues',
#   'Genre': ['Blues'],
#   'Date': '12/15/2017',
#   'Location': 'Germany'},
#  {'Name': 'Snowball',
#   'Genre': ['Lindy', 'Balboa', 'Solo Jazz'],
#   'Date': '12/26/2017',
#   'Location': 'Sweden'},
#  {'Name': 'Bubbly Blues',
#   'Genre': ['Blues'],
#   'Date': '12/29/2017',
#   'Location': 'Germany'},
#  {'Name': 'The CountDown',
#   'Genre': ['Fusion'],
#   'Date': '12/29/2017',
#   'Location': 'France'},
#  {'Name': 'Tropic Thunder Swing Fest 2017',
#   'Genre': ['Lindy'],
#   'Date': '12/29/2017',
#   'Location': 'Malaysia'}]

# %%
lindy_df = pd.DataFrame(lindy_list)
lindy_df.head()
# Out:
#         Date               Genre Location                               Name
# 0   1/3/2016     [Lindy, Balboa]   Russia  Moscow Christmas Swing Dance Camp
# 1   1/8/2016  [Lindy, Solo Jazz]   Poland              Krakow Lindy Invasion
# 2  1/15/2016            [Balboa]      USA     California Balboa Classic 2016
# 3  1/15/2016            [Fusion]      USA       City In Motion Dance Weekend
# 4  1/15/2016             [Lindy]      USA      DecoDance at Art Deco Weekend

# %%
lindy_codes = pd.merge(lindy_df, country_codes, on="Location", how="left")
lindy_codes.head()
# Out:
#         Date               Genre Location                               Name  \
# 0   1/3/2016     [Lindy, Balboa]   Russia  Moscow Christmas Swing Dance Camp
# 1   1/8/2016  [Lindy, Solo Jazz]   Poland              Krakow Lindy Invasion
# 2  1/15/2016            [Balboa]      USA     California Balboa Classic 2016
# 3  1/15/2016            [Fusion]      USA       City In Motion Dance Weekend
# 4  1/15/2016             [Lindy]      USA      DecoDance at Art Deco Weekend
#
#   Code
# 0  NaN
# 1  POL
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# BAD PRACTICE, CHANGE!!!
for index, row in lindy_codes.iterrows():
    if row["Location"] == "USA":
        row["Code"] = "USA"
    if row["Location"] == "Russia":
        row["Code"] = "RUS"

# %%
test = lindy_codes.groupby(['Code']).count().reset_index()
test[["Code", "Name"]]
# Out:
#    Code  Name
# 0   ARG     3
# 1   AUS    26
# 2   AUT     6
# 3   BEL     6
# 4   BLR     2
# 5   BRA     1
# 6   CAN    28
# 7   CHE    10
# 8   CHL     1
# 9   CHN     1
# 10  CUB     1
# 11  CZE     3
# 12  DEU    39
# 13  DNK     6
# 14  ESP    27
# 15  EST     3
# 16  FRA    29
# 17  GBR    43
# 18  GRC     1
# 19  HKG     1
# 20  HRV     1
# 21  HUN     1
# 22  IRL     3
# 23  ISL     1
# 24  ISR     2
# 25  ITA    13
# 26  JAM     1
# 27  JPN     1
# 28  LTU     4
# 29  MEX     3
# 30  MOZ     1
# 31  MYS     2
# 32  NLD     9
# 33  NOR     3
# 34  NZL     5
# 35  POL    13
# 36  PRI     1
# 37  PRT     4
# 38  RUS     6
# 39  SGP     2
# 40  SVN     4
# 41  SWE    23
# 42  THA     1
# 43  TUR     1
# 44  UKR     2
# 45  USA   340
# 46  ZAF     2

# %%
data = [ dict(
        type = 'choropleth',
        locations = test['Code'],
        z = test['Name'],
        text = test['Code'],
        colorscale = [[0,"rgb(5, 10, 172)"],[0.35,"rgb(40, 60, 190)"],[0.5,"rgb(70, 100, 245)"],\
            [0.6,"rgb(90, 120, 245)"],[0.7,"rgb(106, 137, 247)"],[1,"rgb(220, 220, 220)"]],
        autocolorscale = False,
        reversescale = True,
        marker = dict(
            line = dict (
                color = 'rgb(180,180,180)',
                width = 0.5
            ) ),
        colorbar = dict(
            autotick = False,
            title = 'Lindy Events'),
      ) ]

layout = dict(
    title = '2014 Global GDP<br>Source:\
            <a href="https://www.cia.gov/library/publications/the-world-factbook/fields/2195.html">\
            CIA World Factbook</a>',
    geo = dict(
        showframe = False,
        showcoastlines = False,
        projection = dict(
            type = 'Mercator'
        )
    )
)

fig = dict( data=data, layout=layout )
py.iplot( fig, validate=False, filename='d3-world-map' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~lauraraynes/24.embed" height="525px" width="100%"></iframe>
